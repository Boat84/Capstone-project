# %%
import re
import pandas as pd
import os
import csv
from charset_normalizer import from_path

# Function to read screenplay

def read_screenplay(file_path):
    result = from_path(file_path).best()
    with open(file_path, 'r', encoding=result.encoding) as file:
        text = file.read()
    print("Screenplay text loaded.")
    return text

# Function to identify scenes using DataFrame
def identify_scenes(text, title):
    # Compile the regular expressions
    ext_pattern = re.compile(r'\bEXT[.\:\s\-\–\,]', re.MULTILINE)
    int_pattern = re.compile(r'INT[.\:\s\-\–\,]', re.MULTILINE)
    uppercase_pattern = re.compile(r'^[A-Z0-9\s:\(\)\-\.\:\,]+$', re.MULTILINE)
    fade_pattern = re.compile(r'\bFADE OUT[.\:\s\-\–\,]', re.MULTILINE)
    cut_pattern = re.compile(r'\bCUT TO[.\:\s\-\–\,]', re.MULTILINE)
    dissolve_pattern = re.compile(r'\bDISSOLVE[.\:\s\-\–\,]', re.MULTILINE)
    smash_pattern = re.compile(r'\bSMASH CUT[.\:\s\-\–\,]', re.MULTILINE)
    scene_pattern = re.compile(r'(?m)^\[Scene:?\s.*?\,\]$', re.MULTILINE)
    
    # Split text into lines
    lines = text.splitlines()
    
    # Create a DataFrame from lines
    df = pd.DataFrame(lines, columns=['line'])
    
    # Add a column to store matches
    df['match'] = None
    
    # Define match function
    def match_line(line, pattern, match_type):
        if pattern.search(line):
            return match_type
        return None
    
    # First pass: EXT and INT matches
    df['match'] = df['line'].apply(lambda x: match_line(x, ext_pattern, 'EXT') or match_line(x, int_pattern, 'INT') or match_line(x, scene_pattern, 'SCENE')
                                   or match_line(x, fade_pattern, 'FADE OUT') or match_line(x, cut_pattern, 'CUT TO'))
    
    # Second pass: Uppercase lines if less than 150 matches found
    if df['match'].count() < 150:
        df['match'] = df.apply(lambda x: 'UPPERCASE' if (uppercase_pattern.match(x['line']) and pd.isna(x['match']) and len(x['line'].split()) >= 3) else x['match'], axis=1)
    
    # Third pass: Fade, cut, dissolve, smash, and scene pattern matches if still less than 150 matches
    if df['match'].count() < 150:
        df['match'] = df.apply(lambda x: (
            'FADE OUT' if fade_pattern.search(x['line']) else
            'CUT TO' if cut_pattern.search(x['line']) else
            'DISSOLVE' if dissolve_pattern.search(x['line']) else
            'SMASH CUT' if smash_pattern.search(x['line']) else
            'SCENE' if scene_pattern.search(x['line']) else
            x['match']
        ), axis=1)
    
    # Collect matches
    matches = []
    match_counter = 1
    for index, row in df.iterrows():
        if pd.notna(row['match']):
            matches.append(f"{row['line']} SCENE{match_counter:03d}")
            match_counter += 1
    
    print(f"{title}: {len(matches)} matches found")
    
    return matches

# Function to extract scenes
def extract_scenes(text, matches):
    scenes = {}
    for i in range(len(matches)):
        scene_title = matches[i]
        numbered_scene_title = scene_title.split(' SCENE')[0]
        scene_id = scene_title.split(' SCENE')[1]
        start_pos = text.find(numbered_scene_title)

        if i + 1 < len(matches):
            next_scene_title = matches[i + 1].split(' SCENE')[0]
            end_pos = text.find(next_scene_title, start_pos + len(numbered_scene_title))
        else:
            end_pos = len(text)

        scene_text = text[start_pos:end_pos].strip()
        unique_scene_title = f"{scene_id} {numbered_scene_title}"
        scenes[unique_scene_title] = scene_text

    print(f"Extracted {len(scenes)} scenes")
    
    return scenes

# Function to clean scene text
def clean_scene_text(scene_text):
    lines = scene_text.splitlines()
    cleaned_lines = [re.sub(r'\s+', ' ', line.strip()) for line in lines]
    cleaned_text = "\n".join(cleaned_lines)
    return cleaned_text

# Function to save scene separated text to new file
def save_scenes_to_file(file_path, scenes):
    new_dir = 'data/screenplay_data/data/scene_separated_texts'
    if not os.path.exists(new_dir):
        os.makedirs(new_dir)
    
    filename = os.path.basename(file_path)
    new_file_path = os.path.join(new_dir, filename)
    
    with open(new_file_path, 'w', encoding='utf-8') as file:
        file.write(f"Scene count: {len(scenes)}\n\n")
        
        for i, (scene_title, scene_content) in enumerate(scenes.items(), start=1):
            cleaned_scene_content = clean_scene_text(scene_content)
            file.write("=" * 50 + "\n")
            file.write(f"{cleaned_scene_content}\n\n")
    
    print(f"Scene-separated screenplay saved to {new_file_path}")

# Function that combines previous functions
def process_screenplay(file_path):
    filename = os.path.basename(file_path)
    title = filename.split('_')[0]
    
    text = read_screenplay(file_path)
    scene_headings = identify_scenes(text, title)
    scenes = extract_scenes(text, scene_headings)
    save_scenes_to_file(file_path, scenes)
    
    return title, len(scene_headings)

# Function to process all screenplays in the raw_texts folder and create summary file
def process_all_screenplays(folder_path, summary_file_path):
    summary = []

    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):
            file_path = os.path.join(folder_path, filename)
            print(f"Processing file: {filename}")
            
            try:
                title, scene_count = process_screenplay(file_path)
                summary.append((title, scene_count))
            except Exception as e:
                print(f"Error processing file {filename}: {e}")
    
    print("Summary list:", summary)

    try:
        with open(summary_file_path, 'w', encoding='utf-8', newline='') as summary_file:
            writer = csv.writer(summary_file)
            writer.writerow(['Title', 'Scene Count'])
            writer.writerows(summary)
        
        print(f"Summary of processed files saved to {summary_file_path}")
    except Exception as e:
        print(f"Error saving summary to CSV: {e}")

# %%
# Run the function
folder_path = 'data/screenplay_data/data/raw_texts/raw_texts'
summary_file_path = 'data/screenplay_data/data/scene_separated_texts/processed_files_summary.csv'
process_all_screenplays(folder_path, summary_file_path)
# Out:
# Processing file: 10 Cloverfield Lane_1179933.txt
# Screenplay text loaded.
# 10 Cloverfield Lane: 133 matches found
# Extracted 133 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\10 Cloverfield Lane_1179933.txt
# Processing file: 10 Things I Hate About You_0147800.txt
# Screenplay text loaded.
# 10 Things I Hate About You: 122 matches found
# Extracted 122 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\10 Things I Hate About You_0147800.txt
# Processing file: 12 Monkeys_0114746.txt
# Screenplay text loaded.
# 12 Monkeys: 176 matches found
# Extracted 176 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\12 Monkeys_0114746.txt
# Processing file: 12 Years a Slave_2024544.txt
# Screenplay text loaded.
# 12 Years a Slave: 155 matches found
# Extracted 155 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\12 Years a Slave_2024544.txt
# Processing file: 127 Hours_1542344.txt
# Screenplay text loaded.
# 127 Hours: 460 matches found
# Extracted 460 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\127 Hours_1542344.txt
# Processing file: 1408_0450385.txt
# Screenplay text loaded.
# 1408: 240 matches found
# Extracted 240 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\1408_0450385.txt
# Processing file: 15 Minutes_0179626.txt
# Screenplay text loaded.
# 15 Minutes: 107 matches found
# Extracted 107 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\15 Minutes_0179626.txt
# Processing file: 16 Blocks_0450232.txt
# Screenplay text loaded.
# 16 Blocks: 167 matches found
# Extracted 167 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\16 Blocks_0450232.txt
# Processing file: 17 Again_0974661.txt
# Screenplay text loaded.
# 17 Again: 132 matches found
# Extracted 132 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\17 Again_0974661.txt
# Processing file: 1917_8579674.txt
# Screenplay text loaded.
# 1917: 78 matches found
# Extracted 78 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\1917_8579674.txt
# Processing file: 2012_1190080.txt
# Screenplay text loaded.
# 2012: 302 matches found
# Extracted 302 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\2012_1190080.txt
# Processing file: 21 Grams_0315733.txt
# Screenplay text loaded.
# 21 Grams: 175 matches found
# Extracted 175 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\21 Grams_0315733.txt
# Processing file: 21 Jump Street_1232829.txt
# Screenplay text loaded.
# 21 Jump Street: 162 matches found
# Extracted 161 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\21 Jump Street_1232829.txt
# Processing file: 28 Weeks Later_0463854.txt
# Screenplay text loaded.
# 28 Weeks Later: 210 matches found
# Extracted 210 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\28 Weeks Later_0463854.txt
# Processing file: 3 10 to Yuma_0381849.txt
# Screenplay text loaded.
# 3 10 to Yuma: 187 matches found
# Extracted 187 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\3 10 to Yuma_0381849.txt
# Processing file: 30 Days of Night_0389722.txt
# Screenplay text loaded.
# 30 Days of Night: 189 matches found
# Extracted 189 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\30 Days of Night_0389722.txt
# Processing file: 30 Minutes or Less_1622547.txt
# Screenplay text loaded.
# 30 Minutes or Less: 129 matches found
# Extracted 129 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\30 Minutes or Less_1622547.txt
# Processing file: 42_0453562.txt
# Screenplay text loaded.
# 42: 260 matches found
# Extracted 260 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\42_0453562.txt
# Processing file: 47 Ronin_1335975.txt
# Screenplay text loaded.
# 47 Ronin: 230 matches found
# Extracted 230 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\47 Ronin_1335975.txt
# Processing file: 8MM_0134273.txt
# Screenplay text loaded.
# 8MM: 284 matches found
# Extracted 284 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\8MM_0134273.txt
# Processing file: A Beautiful Day in the Neighborhood_3224458.txt
# Screenplay text loaded.
# A Beautiful Day in the Neighborhood: 130 matches found
# Extracted 130 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Beautiful Day in the Neighborhood_3224458.txt
# Processing file: A Beautiful Mind_0268978.txt
# Screenplay text loaded.
# A Beautiful Mind: 198 matches found
# Extracted 198 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Beautiful Mind_0268978.txt
# Processing file: A Christmas Story_0085334.txt
# Screenplay text loaded.
# A Christmas Story: 190 matches found
# Extracted 189 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Christmas Story_0085334.txt
# Processing file: A Dangerous Method_1571222.txt
# Screenplay text loaded.
# A Dangerous Method: 137 matches found
# Extracted 137 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Dangerous Method_1571222.txt
# Processing file: A Few Good Men_0104257.txt
# Screenplay text loaded.
# A Few Good Men: 157 matches found
# Extracted 157 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Few Good Men_0104257.txt
# Processing file: A Good Year_0401445.txt
# Screenplay text loaded.
# A Good Year: 195 matches found
# Extracted 195 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Good Year_0401445.txt
# Processing file: A History of Violence_0399146.txt
# Screenplay text loaded.
# A History of Violence: 128 matches found
# Extracted 128 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A History of Violence_0399146.txt
# Processing file: A Mighty Heart_0829459.txt
# Screenplay text loaded.
# A Mighty Heart: 180 matches found
# Extracted 180 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Mighty Heart_0829459.txt
# Processing file: A Monster Calls_3416532.txt
# Screenplay text loaded.
# A Monster Calls: 43 matches found
# Extracted 43 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Monster Calls_3416532.txt
# Processing file: A Night at the Roxbury_0120770.txt
# Screenplay text loaded.
# A Night at the Roxbury: 215 matches found
# Extracted 215 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Night at the Roxbury_0120770.txt
# Processing file: A Nightmare on Elm Street 4 The Dream Master_0095742.txt
# Screenplay text loaded.
# A Nightmare on Elm Street 4 The Dream Master: 175 matches found
# Extracted 175 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Nightmare on Elm Street 4 The Dream Master_0095742.txt
# Processing file: A Nightmare on Elm Street_0087800.txt
# Screenplay text loaded.
# A Nightmare on Elm Street: 157 matches found
# Extracted 157 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Nightmare on Elm Street_0087800.txt
# Processing file: A Perfect Getaway_0971209.txt
# Screenplay text loaded.
# A Perfect Getaway: 161 matches found
# Extracted 161 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Perfect Getaway_0971209.txt
# Processing file: A Quiet Place_6644200.txt
# Screenplay text loaded.
# A Quiet Place: 209 matches found
# Extracted 209 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Quiet Place_6644200.txt
# Processing file: A Scanner Darkly_0405296.txt
# Screenplay text loaded.
# A Scanner Darkly: 210 matches found
# Extracted 210 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Scanner Darkly_0405296.txt
# Processing file: A Simple Favor_7040874.txt
# Screenplay text loaded.
# A Simple Favor: 183 matches found
# Extracted 183 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Simple Favor_7040874.txt
# Processing file: A Simple Plan_0120324.txt
# Screenplay text loaded.
# A Simple Plan: 252 matches found
# Extracted 229 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Simple Plan_0120324.txt
# Processing file: A Single Man_1315981.txt
# Screenplay text loaded.
# A Single Man: 185 matches found
# Extracted 185 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Single Man_1315981.txt
# Processing file: About Time_2194499.txt
# Screenplay text loaded.
# About Time: 171 matches found
# Extracted 171 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\About Time_2194499.txt
# Processing file: Absolute Power_0118548.txt
# Screenplay text loaded.
# Absolute Power: 354 matches found
# Extracted 354 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Absolute Power_0118548.txt
# Processing file: Ad Astra_2935510.txt
# Screenplay text loaded.
# Ad Astra: 171 matches found
# Extracted 171 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Ad Astra_2935510.txt
# Processing file: After Earth_1815862.txt
# Screenplay text loaded.
# After Earth: 434 matches found
# Extracted 434 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\After Earth_1815862.txt
# Processing file: Air Force One_0118571.txt
# Screenplay text loaded.
# Air Force One: 338 matches found
# Extracted 338 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Air Force One_0118571.txt
# Processing file: Alfie_0375173.txt
# Screenplay text loaded.
# Alfie: 168 matches found
# Extracted 168 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alfie_0375173.txt
# Processing file: Alice in Wonderland_1014759.txt
# Screenplay text loaded.
# Alice in Wonderland: 201 matches found
# Extracted 201 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alice in Wonderland_1014759.txt
# Processing file: Alien Covenant_2316204.txt
# Screenplay text loaded.
# Alien Covenant: 160 matches found
# Extracted 160 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alien Covenant_2316204.txt
# Processing file: Alien Resurrection_0118583.txt
# Screenplay text loaded.
# Alien Resurrection: 171 matches found
# Extracted 171 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alien Resurrection_0118583.txt
# Processing file: Aliens_0090605.txt
# Screenplay text loaded.
# Aliens: 201 matches found
# Extracted 201 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Aliens_0090605.txt
# Processing file: Alien_0078748.txt
# Screenplay text loaded.
# Alien: 278 matches found
# Extracted 278 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alien_0078748.txt
# Processing file: Ali_0248667.txt
# Screenplay text loaded.
# Ali: 210 matches found
# Extracted 210 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Ali_0248667.txt
# Processing file: All About Steve_0881891.txt
# Screenplay text loaded.
# All About Steve: 194 matches found
# Extracted 194 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\All About Steve_0881891.txt
# Processing file: All the King s Men_0041113.txt
# Screenplay text loaded.
# All the King s Men: 112 matches found
# Extracted 112 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\All the King s Men_0041113.txt
# Processing file: All the Money in the World_5294550.txt
# Screenplay text loaded.
# All the Money in the World: 213 matches found
# Extracted 213 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\All the Money in the World_5294550.txt
# Processing file: Almost Famous_0181875.txt
# Screenplay text loaded.
# Almost Famous: 185 matches found
# Extracted 185 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Almost Famous_0181875.txt
# Processing file: Alone in the Dark_0369226.txt
# Screenplay text loaded.
# Alone in the Dark: 162 matches found
# Extracted 162 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alone in the Dark_0369226.txt
# Processing file: Amadeus_0086879.txt
# Screenplay text loaded.
# Amadeus: 228 matches found
# Extracted 228 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Amadeus_0086879.txt
# Processing file: Amelia_1129445.txt
# Screenplay text loaded.
# Amelia: 178 matches found
# Extracted 178 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Amelia_1129445.txt
# Processing file: American Gangster_0765429.txt
# Screenplay text loaded.
# American Gangster: 310 matches found
# Extracted 310 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Gangster_0765429.txt
# Processing file: American History X_0120586.txt
# Screenplay text loaded.
# American History X: 187 matches found
# Extracted 187 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American History X_0120586.txt
# Processing file: American Hustle_1800241.txt
# Screenplay text loaded.
# American Hustle: 174 matches found
# Extracted 174 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Hustle_1800241.txt
# Processing file: American Outlaws_0244000.txt
# Screenplay text loaded.
# American Outlaws: 169 matches found
# Extracted 169 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Outlaws_0244000.txt
# Processing file: American Psycho_0144084.txt
# Screenplay text loaded.
# American Psycho: 71 matches found
# Extracted 71 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Psycho_0144084.txt
# Processing file: American Splendor_0305206.txt
# Screenplay text loaded.
# American Splendor: 212 matches found
# Extracted 212 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Splendor_0305206.txt
# Processing file: American Ultra_3316948.txt
# Screenplay text loaded.
# American Ultra: 188 matches found
# Extracted 188 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Ultra_3316948.txt
# Processing file: An Officer and a Gentleman_0084434.txt
# Screenplay text loaded.
# An Officer and a Gentleman: 156 matches found
# Extracted 156 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\An Officer and a Gentleman_0084434.txt
# Processing file: Anaconda_0118615.txt
# Screenplay text loaded.
# Anaconda: 223 matches found
# Extracted 223 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Anaconda_0118615.txt
# Processing file: Analyze That_0289848.txt
# Screenplay text loaded.
# Analyze That: 251 matches found
# Extracted 251 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Analyze That_0289848.txt
# Processing file: Analyze This_0122933.txt
# Screenplay text loaded.
# Analyze This: 180 matches found
# Extracted 180 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Analyze This_0122933.txt
# Processing file: Anastasia_0118617.txt
# Screenplay text loaded.
# Anastasia: 151 matches found
# Extracted 151 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Anastasia_0118617.txt
# Processing file: Angel Eyes_0225071.txt
# Screenplay text loaded.
# Angel Eyes: 154 matches found
# Extracted 151 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Angel Eyes_0225071.txt
# Processing file: Angels Demons_0808151.txt
# Screenplay text loaded.
# Angels Demons: 212 matches found
# Extracted 212 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Angels Demons_0808151.txt
# Processing file: Animal Kingdom_1313092.txt
# Screenplay text loaded.
# Animal Kingdom: 176 matches found
# Extracted 176 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Animal Kingdom_1313092.txt
# Processing file: Anna Karenina_1781769.txt
# Screenplay text loaded.
# Anna Karenina: 265 matches found
# Extracted 265 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Anna Karenina_1781769.txt
# Processing file: Annabelle_3322940.txt
# Screenplay text loaded.
# Annabelle: 150 matches found
# Extracted 150 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Annabelle_3322940.txt
# Processing file: Annie Hall_0075686.txt
# Screenplay text loaded.
# Annie Hall: 145 matches found
# Extracted 145 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Annie Hall_0075686.txt
# Processing file: Annihilation_2798920.txt
# Screenplay text loaded.
# Annihilation: 159 matches found
# Extracted 159 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Annihilation_2798920.txt
# Processing file: Anonymous_1521197.txt
# Screenplay text loaded.
# Anonymous: 220 matches found
# Extracted 220 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Anonymous_1521197.txt
# Processing file: Antitrust_0218817.txt
# Screenplay text loaded.
# Antitrust: 262 matches found
# Extracted 262 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Antitrust_0218817.txt
# Processing file: Antz_0120587.txt
# Screenplay text loaded.
# Antz: 85 matches found
# Extracted 85 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Antz_0120587.txt
# Processing file: Any Given Sunday_0146838.txt
# Screenplay text loaded.
# Any Given Sunday: 213 matches found
# Extracted 210 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Any Given Sunday_0146838.txt
# Processing file: Apocalypse Now_0078788.txt
# Screenplay text loaded.
# Apocalypse Now: 324 matches found
# Extracted 324 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Apocalypse Now_0078788.txt
# Processing file: April Fool s Day_0090655.txt
# Screenplay text loaded.
# April Fool s Day: 172 matches found
# Extracted 172 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\April Fool s Day_0090655.txt
# Processing file: Aquaman_1477834.txt
# Screenplay text loaded.
# Aquaman: 168 matches found
# Extracted 168 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Aquaman_1477834.txt
# Processing file: Arbitrage_1764183.txt
# Screenplay text loaded.
# Arbitrage: 121 matches found
# Extracted 121 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Arbitrage_1764183.txt
# Processing file: Argo_1024648.txt
# Screenplay text loaded.
# Argo: 325 matches found
# Extracted 325 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Argo_1024648.txt
# Processing file: Arrival_2543164.txt
# Screenplay text loaded.
# Arrival: 168 matches found
# Extracted 168 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Arrival_2543164.txt
# Processing file: Arthur_1334512.txt
# Screenplay text loaded.
# Arthur: 159 matches found
# Extracted 159 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Arthur_1334512.txt
# Processing file: As Above So Below_2870612.txt
# Screenplay text loaded.
# As Above So Below: 139 matches found
# Extracted 139 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\As Above So Below_2870612.txt
# Processing file: Assassination Nation_6205872.txt
# Screenplay text loaded.
# Assassination Nation: 155 matches found
# Extracted 155 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Assassination Nation_6205872.txt
# Processing file: Assassins_0112401.txt
# Screenplay text loaded.
# Assassins: 182 matches found
# Extracted 182 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Assassins_0112401.txt
# Processing file: At First Sight_0132512.txt
# Screenplay text loaded.
# At First Sight: 155 matches found
# Extracted 155 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\At First Sight_0132512.txt
# Processing file: Atomic Blonde_2406566.txt
# Screenplay text loaded.
# Atomic Blonde: 164 matches found
# Extracted 163 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Atomic Blonde_2406566.txt
# Processing file: Atonement_0783233.txt
# Screenplay text loaded.
# Atonement: 171 matches found
# Extracted 171 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Atonement_0783233.txt
# Processing file: August Osage County_1322269.txt.txt
# Screenplay text loaded.
# August Osage County: 225 matches found
# Extracted 225 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\August Osage County_1322269.txt.txt
# Processing file: Austin Powers International Man of Mystery_0118655.txt
# Screenplay text loaded.
# Austin Powers International Man of Mystery: 224 matches found
# Extracted 221 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Austin Powers International Man of Mystery_0118655.txt
# Processing file: Austin Powers The Spy Who Shagged Me_0145660.txt
# Screenplay text loaded.
# Austin Powers The Spy Who Shagged Me: 199 matches found
# Extracted 199 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Austin Powers The Spy Who Shagged Me_0145660.txt
# Processing file: Autumn in New York_0174480.txt
# Screenplay text loaded.
# Autumn in New York: 152 matches found
# Extracted 152 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Autumn in New York_0174480.txt
# Processing file: Avatar_0499549.txt
# Screenplay text loaded.
# Avatar: 251 matches found
# Extracted 251 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Avatar_0499549.txt
# Processing file: Avengers Endgame_4154796.txt
# Screenplay text loaded.
# Avengers Endgame: 271 matches found
# Extracted 271 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Avengers Endgame_4154796.txt
# Processing file: Awakenings_0099077.txt
# Screenplay text loaded.
# Awakenings: 155 matches found
# Extracted 155 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Awakenings_0099077.txt
# Processing file: Awake_0211933.txt
# Screenplay text loaded.
# Awake: 144 matches found
# Extracted 144 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Awake_0211933.txt
# Processing file: Baby Driver_3890160.txt
# Screenplay text loaded.
# Baby Driver: 142 matches found
# Extracted 142 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Baby Driver_3890160.txt
# Processing file: Back to the Future Part II_0096874.txt
# Screenplay text loaded.
# Back to the Future Part II: 187 matches found
# Extracted 187 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Back to the Future Part II_0096874.txt
# Processing file: Back to the Future_0088763.txt
# Screenplay text loaded.
# Back to the Future: 273 matches found
# Extracted 273 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Back to the Future_0088763.txt
# Processing file: Bad Santa_0307987.txt
# Screenplay text loaded.
# Bad Santa: 151 matches found
# Extracted 151 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Bad Santa_0307987.txt
# Processing file: Bad Teacher_1284575.txt
# Screenplay text loaded.
# Bad Teacher: 155 matches found
# Extracted 155 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Bad Teacher_1284575.txt
# Processing file: Bad Times at the El Royale_6628394.txt
# Screenplay text loaded.
# Bad Times at the El Royale: 221 matches found
# Extracted 221 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Bad Times at the El Royale_6628394.txt
# Processing file: Barry Lyndon_0072684.txt
# Screenplay text loaded.
# Barry Lyndon: 242 matches found
# Extracted 242 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Barry Lyndon_0072684.txt
# Processing file: Basquiat_0115632.txt
# Screenplay text loaded.
# Basquiat: 141 matches found
# Extracted 141 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Basquiat_0115632.txt
# Processing file: Batman Begins_0372784.txt
# Screenplay text loaded.
# Batman Begins: 330 matches found
# Extracted 330 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Batman Begins_0372784.txt
# Processing file: Batman Forever_0112462.txt
# Screenplay text loaded.
# Batman Forever: 169 matches found
# Extracted 169 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Batman Forever_0112462.txt
# Processing file: Batman Returns_0103776.txt
# Screenplay text loaded.
# Batman Returns: 275 matches found
# Extracted 275 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Batman Returns_0103776.txt
# Processing file: Batman Robin_0118688.txt
# Screenplay text loaded.
# Batman Robin: 206 matches found
# Extracted 206 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Batman Robin_0118688.txt
# Processing file: Batman v Superman Dawn of Justice_2975590.txt
# Screenplay text loaded.
# Batman v Superman Dawn of Justice: 216 matches found
# Extracted 216 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Batman v Superman Dawn of Justice_2975590.txt
# Processing file: Batman_0096895.txt
# Screenplay text loaded.
# Batman: 253 matches found
# Extracted 253 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Batman_0096895.txt
# Processing file: Bats_0200469.txt
# Screenplay text loaded.
# Bats: 138 matches found
# Extracted 137 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Bats_0200469.txt
# Processing file: Battle for the Planet of the Apes_0069768.txt
# Screenplay text loaded.
# Battle for the Planet of the Apes: 52 matches found
# Extracted 52 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Battle for the Planet of the Apes_0069768.txt
# Processing file: Battle of the Sexes_4622512.txt
# Screenplay text loaded.
# Battle of the Sexes: 159 matches found
# Extracted 159 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Battle of the Sexes_4622512.txt
# Processing file: Beasts of No Nation_1365050.txt
# Screenplay text loaded.
# Beasts of No Nation: 162 matches found
# Extracted 162 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Beasts of No Nation_1365050.txt
# Processing file: Beasts of the Southern Wild_2125435.txt
# Screenplay text loaded.
# Beasts of the Southern Wild: 136 matches found
# Extracted 136 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Beasts of the Southern Wild_2125435.txt
# Processing file: Beauty and the Beast_0038348.txt
# Screenplay text loaded.
# Beauty and the Beast: 3 matches found
# Extracted 3 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Beauty and the Beast_0038348.txt
# Processing file: Beauty and the Beast_2771200.txt
# Screenplay text loaded.
# Beauty and the Beast: 175 matches found
# Extracted 175 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Beauty and the Beast_2771200.txt
# Processing file: Beavis and Butt Head Do America_0115641.txt
# Screenplay text loaded.
# Beavis and Butt Head Do America: 180 matches found
# Extracted 180 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Beavis and Butt Head Do America_0115641.txt
# Processing file: Beetlejuice_0094721.txt
# Screenplay text loaded.
# Beetlejuice: 218 matches found
# Extracted 216 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Beetlejuice_0094721.txt
# Processing file: Before Midnight_2209418.txt
# Screenplay text loaded.
# Before Midnight: 25 matches found
# Extracted 25 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Before Midnight_2209418.txt
# Processing file: Before Sunrise_0112471.txt
# Screenplay text loaded.
# Before Sunrise: 45 matches found
# Extracted 45 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Before Sunrise_0112471.txt
# Processing file: Before Sunset_0381681.txt
# Screenplay text loaded.
# Before Sunset: 16 matches found
# Extracted 16 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Before Sunset_0381681.txt
# Processing file: Being John Malkovich_0120601.txt
# Screenplay text loaded.
# Being John Malkovich: 331 matches found
# Extracted 331 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Being John Malkovich_0120601.txt
# Processing file: Beloved_0120603.txt
# Screenplay text loaded.
# Beloved: 215 matches found
# Extracted 215 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Beloved_0120603.txt
# Processing file: Beneath the Planet of the Apes_0065462.txt
# Screenplay text loaded.
# Beneath the Planet of the Apes: 206 matches found
# Extracted 206 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Beneath the Planet of the Apes_0065462.txt
# Processing file: Beowulf_0442933.txt
# Screenplay text loaded.
# Beowulf: 175 matches found
# Extracted 175 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Beowulf_0442933.txt
# Processing file: Beverly Hills Cop_0086960.txt
# Screenplay text loaded.
# Beverly Hills Cop: 215 matches found
# Extracted 215 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Beverly Hills Cop_0086960.txt
# Processing file: Big Eyes_1126590.txt
# Screenplay text loaded.
# Big Eyes: 175 matches found
# Extracted 175 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Big Eyes_1126590.txt
# Processing file: Big Fish_0319061.txt
# Screenplay text loaded.
# Big Fish: 207 matches found
# Extracted 207 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Big Fish_0319061.txt
# Processing file: Big Trouble in Little China_0090728.txt
# Screenplay text loaded.
# Big Trouble in Little China: 146 matches found
# Extracted 146 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Big Trouble in Little China_0090728.txt
# Processing file: Big_0094737.txt
# Screenplay text loaded.
# Big: 0 matches found
# Extracted 0 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Big_0094737.txt
# Processing file: Bill Ted Face the Music_1086064.txt
# Screenplay text loaded.
# Bill Ted Face the Music: 296 matches found
# Extracted 296 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Bill Ted Face the Music_1086064.txt
# Processing file: Bill Ted s Bogus Journey_0101452.txt
# Screenplay text loaded.
# Bill Ted s Bogus Journey: 297 matches found
# Extracted 297 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Bill Ted s Bogus Journey_0101452.txt
# Processing file: Black Christmas_0454082.txt
# Screenplay text loaded.
# Black Christmas: 289 matches found
# Extracted 289 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Black Christmas_0454082.txt
# Processing file: Black Hawk Down_0265086.txt
# Screenplay text loaded.
# Black Hawk Down: 292 matches found
# Extracted 292 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Black Hawk Down_0265086.txt
# Processing file: Black Panther_1825683.txt
# Screenplay text loaded.
# Black Panther: 201 matches found
# Extracted 201 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Black Panther_1825683.txt
# Processing file: Black Rain_0096933.txt
# Screenplay text loaded.
# Black Rain: 194 matches found
# Extracted 194 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Black Rain_0096933.txt
# Processing file: Black Swan_0947798.txt
# Screenplay text loaded.
# Black Swan: 151 matches found
# Extracted 151 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Black Swan_0947798.txt
# Processing file: BlacKkKlansman_7349662.txt
# Screenplay text loaded.
# BlacKkKlansman: 193 matches found
# Extracted 193 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\BlacKkKlansman_7349662.txt
# Processing file: Blade Runner_0083658.txt
# Screenplay text loaded.
# Blade Runner: 133 matches found
# Extracted 133 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Blade Runner_0083658.txt
# Processing file: Blade Trinity_0359013.txt
# Screenplay text loaded.
# Blade Trinity: 209 matches found
# Extracted 209 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Blade Trinity_0359013.txt
# Processing file: Blade_0120611.txt
# Screenplay text loaded.
# Blade: 179 matches found
# Extracted 179 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Blade_0120611.txt
# Processing file: Blast from the Past_0124298.txt
# Screenplay text loaded.
# Blast from the Past: 197 matches found
# Extracted 197 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Blast from the Past_0124298.txt
# Processing file: Blue Valentine_1120985.txt
# Screenplay text loaded.
# Blue Valentine: 247 matches found
# Extracted 247 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Blue Valentine_1120985.txt
# Processing file: Body Double_0086984.txt
# Screenplay text loaded.
# Body Double: 173 matches found
# Extracted 173 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Body Double_0086984.txt
# Processing file: Body of Lies_0758774.txt
# Screenplay text loaded.
# Body of Lies: 211 matches found
# Extracted 211 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Body of Lies_0758774.txt
# Processing file: Boiler Room_0181984.txt
# Screenplay text loaded.
# Boiler Room: 218 matches found
# Extracted 218 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Boiler Room_0181984.txt
# Processing file: Bonnie and Clyde_0061418.txt
# Screenplay text loaded.
# Bonnie and Clyde: 196 matches found
# Extracted 196 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Bonnie and Clyde_0061418.txt
# Processing file: Book of Shadows Blair Witch 2_0229260.txt
# Screenplay text loaded.
# Book of Shadows Blair Witch 2: 148 matches found
# Extracted 148 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Book of Shadows Blair Witch 2_0229260.txt
# Processing file: Born on the Fourth of July_0096969.txt
# Screenplay text loaded.
# Born on the Fourth of July: 153 matches found
# Extracted 153 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Born on the Fourth of July_0096969.txt
# Processing file: Bottle Rocket_0115734.txt
# Screenplay text loaded.
# Bottle Rocket: 110 matches found
# Extracted 110 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Bottle Rocket_0115734.txt
# Processing file: Bound_0115736.txt
# Screenplay text loaded.
# Bound: 179 matches found
# Extracted 179 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Bound_0115736.txt
# Processing file: Boy Erased_7008872.txt
# Screenplay text loaded.
# Boy Erased: 177 matches found
# Extracted 177 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Boy Erased_7008872.txt
# Processing file: Boyz n the Hood_0101507.txt
# Screenplay text loaded.
# Boyz n the Hood: 470 matches found
# Extracted 470 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Boyz n the Hood_0101507.txt
# Processing file: Braveheart_0112573.txt
# Screenplay text loaded.
# Braveheart: 190 matches found
# Extracted 190 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Braveheart_0112573.txt
# Processing file: Brazil_0088846.txt
# Screenplay text loaded.
# Brazil: 163 matches found
# Extracted 163 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Brazil_0088846.txt
# Processing file: Breakdown_0118771.txt
# Screenplay text loaded.
# Breakdown: 182 matches found
# Extracted 182 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Breakdown_0118771.txt
# Processing file: Bridesmaids_1478338.txt
# Screenplay text loaded.
# Bridesmaids: 156 matches found
# Extracted 156 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Bridesmaids_1478338.txt
# Processing file: Bridge of Spies_3682448.txt
# Screenplay text loaded.
# Bridge of Spies: 173 matches found
# Extracted 173 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Bridge of Spies_3682448.txt
# Processing file: Bright Star_0810784.txt
# Screenplay text loaded.
# Bright Star: 156 matches found
# Extracted 156 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Bright Star_0810784.txt
# Processing file: Broken Arrow_0115759.txt
# Screenplay text loaded.
# Broken Arrow: 190 matches found
# Extracted 190 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Broken Arrow_0115759.txt
# Processing file: Bruce Almighty_0315327.txt
# Screenplay text loaded.
# Bruce Almighty: 204 matches found
# Extracted 204 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Bruce Almighty_0315327.txt
# Processing file: Buried_1462758.txt
# Screenplay text loaded.
# Buried: 55 matches found
# Extracted 55 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Buried_1462758.txt
# Processing file: Burlesque_1126591.txt
# Screenplay text loaded.
# Burlesque: 156 matches found
# Extracted 156 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Burlesque_1126591.txt
# Processing file: Burn After Reading_0887883.txt
# Screenplay text loaded.
# Burn After Reading: 151 matches found
# Extracted 151 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Burn After Reading_0887883.txt
# Processing file: Butch Cassidy and the Sundance Kid_0064115.txt
# Screenplay text loaded.
# Butch Cassidy and the Sundance Kid: 278 matches found
# Extracted 278 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Butch Cassidy and the Sundance Kid_0064115.txt
# Processing file: Caddyshack_0080487.txt
# Screenplay text loaded.
# Caddyshack: 220 matches found
# Extracted 220 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Caddyshack_0080487.txt
# Processing file: Call Me by Your Name_5726616.txt
# Screenplay text loaded.
# Call Me by Your Name: 152 matches found
# Extracted 152 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Call Me by Your Name_5726616.txt
# Processing file: Can You Ever Forgive Me_4595882.txt
# Screenplay text loaded.
# Can You Ever Forgive Me: 163 matches found
# Extracted 163 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Can You Ever Forgive Me_4595882.txt
# Processing file: Cape Fear_0055824.txt
# Screenplay text loaded.
# Cape Fear: 179 matches found
# Extracted 179 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Cape Fear_0055824.txt
# Processing file: Captain Phillips_1535109.txt
# Screenplay text loaded.
# Captain Phillips: 266 matches found
# Extracted 266 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Captain Phillips_1535109.txt
# Processing file: Carol_2402927.txt
# Screenplay text loaded.
# Carol: 166 matches found
# Extracted 166 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Carol_2402927.txt
# Processing file: Carrie_0074285.txt
# Screenplay text loaded.
# Carrie: 203 matches found
# Extracted 203 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Carrie_0074285.txt
# Processing file: Cars 2_1216475.txt
# Screenplay text loaded.
# Cars 2: 301 matches found
# Extracted 301 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Cars 2_1216475.txt
# Processing file: Casino Royale_0381061.txt
# Screenplay text loaded.
# Casino Royale: 170 matches found
# Extracted 170 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Casino Royale_0381061.txt
# Processing file: Casino_0112641.txt
# Screenplay text loaded.
# Casino: 445 matches found
# Extracted 445 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Casino_0112641.txt
# Processing file: Cast Away_0162222.txt
# Screenplay text loaded.
# Cast Away: 304 matches found
# Extracted 304 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Cast Away_0162222.txt
# Processing file: Cat People_0034587.txt
# Screenplay text loaded.
# Cat People: 152 matches found
# Extracted 152 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Cat People_0034587.txt
# Processing file: Catwoman_0327554.txt
# Screenplay text loaded.
# Catwoman: 170 matches found
# Extracted 170 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Catwoman_0327554.txt
# Processing file: Cecil B Demented_0173716.txt
# Screenplay text loaded.
# Cecil B Demented: 246 matches found
# Extracted 246 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Cecil B Demented_0173716.txt
# Processing file: Cellular_0337921.txt
# Screenplay text loaded.
# Cellular: 247 matches found
# Extracted 247 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Cellular_0337921.txt
# Processing file: Chain Reaction_0115857.txt
# Screenplay text loaded.
# Chain Reaction: 250 matches found
# Extracted 250 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Chain Reaction_0115857.txt
# Processing file: Changeling_0824747.txt
# Screenplay text loaded.
# Changeling: 191 matches found
# Extracted 191 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Changeling_0824747.txt
# Processing file: Chaos Walking_2076822.txt
# Screenplay text loaded.
# Chaos Walking: 236 matches found
# Extracted 236 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Chaos Walking_2076822.txt
# Processing file: Charlie s Angels_0160127.txt
# Screenplay text loaded.
# Charlie s Angels: 180 matches found
# Extracted 180 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Charlie s Angels_0160127.txt
# Processing file: Chasing Amy_0118842.txt
# Screenplay text loaded.
# Chasing Amy: 45 matches found
# Extracted 45 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Chasing Amy_0118842.txt
# Processing file: Cheaper by the Dozen_0349205.txt
# Screenplay text loaded.
# Cheaper by the Dozen: 216 matches found
# Extracted 216 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Cheaper by the Dozen_0349205.txt
# Processing file: Children of Men_0206634.txt
# Screenplay text loaded.
# Children of Men: 223 matches found
# Extracted 223 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Children of Men_0206634.txt
# Processing file: Chill Factor_0163579.txt
# Screenplay text loaded.
# Chill Factor: 185 matches found
# Extracted 185 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Chill Factor_0163579.txt
# Processing file: Chinatown_0071315.txt
# Screenplay text loaded.
# Chinatown: 115 matches found
# Extracted 115 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Chinatown_0071315.txt
# Processing file: Chocolat_0241303.txt
# Screenplay text loaded.
# Chocolat: 199 matches found
# Extracted 199 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Chocolat_0241303.txt
# Processing file: Chronicle_1706593.txt
# Screenplay text loaded.
# Chronicle: 131 matches found
# Extracted 131 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Chronicle_1706593.txt
# Processing file: Cirque du Freak The Vampire s Assistant_0450405.txt
# Screenplay text loaded.
# Cirque du Freak The Vampire s Assistant: 193 matches found
# Extracted 193 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Cirque du Freak The Vampire s Assistant_0450405.txt
# Processing file: Clash of the Titans_0800320.txt
# Screenplay text loaded.
# Clash of the Titans: 151 matches found
# Extracted 151 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Clash of the Titans_0800320.txt
# Processing file: Click_0389860.txt
# Screenplay text loaded.
# Click: 169 matches found
# Extracted 169 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Click_0389860.txt
# Processing file: Cliffhanger_0106582.txt
# Screenplay text loaded.
# Cliffhanger: 343 matches found
# Extracted 343 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Cliffhanger_0106582.txt
# Processing file: Close Encounters of the Third Kind_0075860.txt
# Screenplay text loaded.
# Close Encounters of the Third Kind: 193 matches found
# Extracted 193 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Close Encounters of the Third Kind_0075860.txt
# Processing file: Cloud Atlas_1371111.txt
# Screenplay text loaded.
# Cloud Atlas: 306 matches found
# Extracted 306 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Cloud Atlas_1371111.txt
# Processing file: Cloudy with a Chance of Meatballs_0844471.txt
# Screenplay text loaded.
# Cloudy with a Chance of Meatballs: 219 matches found
# Extracted 219 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Cloudy with a Chance of Meatballs_0844471.txt
# Processing file: Cloverfield_1060277.txt
# Screenplay text loaded.
# Cloverfield: 221 matches found
# Extracted 221 scenes
# ...
# Screenplay text loaded.
# Up Close Personal: 159 matches found
# Extracted 159 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Up Close Personal_0118055.txt
# Processing file: Up in the Air_1193138.txt
# Screenplay text loaded.
# Up in the Air: 168 matches found
# Extracted 168 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Up in the Air_1193138.txt
# Processing file: Upgrade_6499752.txt
# Screenplay text loaded.
# Upgrade: 187 matches found
# Extracted 187 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Upgrade_6499752.txt
# Processing file: Up_1049413.txt
# Screenplay text loaded.
# Up: 188 matches found
# Extracted 188 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Up_1049413.txt
# Processing file: Urban Legend_0146336.txt
# Screenplay text loaded.
# Urban Legend: 181 matches found
# Extracted 181 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Urban Legend_0146336.txt
# Processing file: Us_6857112.txt
# Screenplay text loaded.
# Us: 203 matches found
# Extracted 203 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Us_6857112.txt
# Processing file: Valentine s Day_0817230.txt
# Screenplay text loaded.
# Valentine s Day: 160 matches found
# Extracted 160 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Valentine s Day_0817230.txt
# Processing file: Valentine_0242998.txt
# Screenplay text loaded.
# Valentine: 166 matches found
# Extracted 159 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Valentine_0242998.txt
# Processing file: Valkyrie_0985699.txt
# Screenplay text loaded.
# Valkyrie: 161 matches found
# Extracted 161 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Valkyrie_0985699.txt
# Processing file: Vanilla Sky_0259711.txt
# Screenplay text loaded.
# Vanilla Sky: 168 matches found
# Extracted 168 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Vanilla Sky_0259711.txt
# Processing file: Vantage Point_0443274.txt
# Screenplay text loaded.
# Vantage Point: 347 matches found
# Extracted 347 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Vantage Point_0443274.txt
# Processing file: Very Bad Things_0124198.txt
# Screenplay text loaded.
# Very Bad Things: 136 matches found
# Extracted 136 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Very Bad Things_0124198.txt
# Processing file: Vicky Cristina Barcelona_0497465.txt
# Screenplay text loaded.
# Vicky Cristina Barcelona: 162 matches found
# Extracted 162 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Vicky Cristina Barcelona_0497465.txt
# Processing file: Victor Frankenstein_1976009.txt
# Screenplay text loaded.
# Victor Frankenstein: 157 matches found
# Extracted 157 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Victor Frankenstein_1976009.txt
# Processing file: Walking Tall_0351977.txt
# Screenplay text loaded.
# Walking Tall: 66 matches found
# Extracted 66 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Walking Tall_0351977.txt
# Processing file: Wall Street_0094291.txt
# Screenplay text loaded.
# Wall Street: 170 matches found
# Extracted 170 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wall Street_0094291.txt
# Processing file: Wanted_0493464.txt
# Screenplay text loaded.
# Wanted: 210 matches found
# Extracted 210 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wanted_0493464.txt
# Processing file: War for the Planet of the Apes_3450958.txt
# Screenplay text loaded.
# War for the Planet of the Apes: 306 matches found
# Extracted 306 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\War for the Planet of the Apes_3450958.txt
# Processing file: War Horse_1568911.txt
# Screenplay text loaded.
# War Horse: 116 matches found
# Extracted 116 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\War Horse_1568911.txt
# Processing file: War of the Worlds_0407304.txt
# Screenplay text loaded.
# War of the Worlds: 58 matches found
# Extracted 58 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\War of the Worlds_0407304.txt
# Processing file: WarGames_0086567.txt
# Screenplay text loaded.
# WarGames: 317 matches found
# Extracted 317 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\WarGames_0086567.txt
# Processing file: Warrior_1291584.txt
# Screenplay text loaded.
# Warrior: 168 matches found
# Extracted 168 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Warrior_1291584.txt
# Processing file: Watchmen_0409459.txt
# Screenplay text loaded.
# Watchmen: 204 matches found
# Extracted 204 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Watchmen_0409459.txt
# Processing file: Water for Elephants_1067583.txt
# Screenplay text loaded.
# Water for Elephants: 150 matches found
# Extracted 150 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Water for Elephants_1067583.txt
# Processing file: Waterworld_0114898.txt
# Screenplay text loaded.
# Waterworld: 158 matches found
# Extracted 158 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Waterworld_0114898.txt
# Processing file: We Bought a Zoo_1389137.txt
# Screenplay text loaded.
# We Bought a Zoo: 162 matches found
# Extracted 162 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\We Bought a Zoo_1389137.txt
# Processing file: We Own the Night_0498399.txt
# Screenplay text loaded.
# We Own the Night: 154 matches found
# Extracted 154 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\We Own the Night_0498399.txt
# Processing file: Wedding Crashers_0396269.txt
# Screenplay text loaded.
# Wedding Crashers: 149 matches found
# Extracted 149 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wedding Crashers_0396269.txt
# Processing file: What Lies Beneath_0161081.txt
# Screenplay text loaded.
# What Lies Beneath: 155 matches found
# Extracted 155 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\What Lies Beneath_0161081.txt
# Processing file: What Women Want_0207201.txt
# Screenplay text loaded.
# What Women Want: 2836 matches found
# Extracted 2836 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\What Women Want_0207201.txt
# Processing file: When a Stranger Calls_0080130.txt
# Screenplay text loaded.
# When a Stranger Calls: 158 matches found
# Extracted 158 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\When a Stranger Calls_0080130.txt
# Processing file: Where the Wild Things Are_0386117.txt
# Screenplay text loaded.
# Where the Wild Things Are: 112 matches found
# Extracted 112 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Where the Wild Things Are_0386117.txt
# Processing file: White House Down_2334879.txt
# Screenplay text loaded.
# White House Down: 286 matches found
# Extracted 286 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\White House Down_2334879.txt
# Processing file: White Squall_0118158.txt
# Screenplay text loaded.
# White Squall: 189 matches found
# Extracted 189 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\White Squall_0118158.txt
# Processing file: Whiteout_0365929.txt
# Screenplay text loaded.
# Whiteout: 160 matches found
# Extracted 157 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Whiteout_0365929.txt
# Processing file: Wild Hogs_0486946.txt
# Screenplay text loaded.
# Wild Hogs: 137 matches found
# Extracted 137 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wild Hogs_0486946.txt
# Processing file: Wild Things_0120890.txt
# Screenplay text loaded.
# Wild Things: 191 matches found
# Extracted 191 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wild Things_0120890.txt
# Processing file: Wild Wild West_0120891.txt
# Screenplay text loaded.
# Wild Wild West: 207 matches found
# Extracted 207 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wild Wild West_0120891.txt
# Processing file: Willard_0310357.txt
# Screenplay text loaded.
# Willard: 213 matches found
# Extracted 213 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Willard_0310357.txt
# Processing file: Win Win_1606392.txt
# Screenplay text loaded.
# Win Win: 133 matches found
# Extracted 133 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Win Win_1606392.txt
# Processing file: Wind River_5362988.txt
# Screenplay text loaded.
# Wind River: 138 matches found
# Extracted 138 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wind River_5362988.txt
# Processing file: Witness_0090329.txt
# Screenplay text loaded.
# Witness: 178 matches found
# Extracted 178 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Witness_0090329.txt
# Processing file: Woman in Gold_2404425.txt
# Screenplay text loaded.
# Woman in Gold: 229 matches found
# Extracted 229 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Woman in Gold_2404425.txt
# Processing file: Wonder Woman_0451279.txt
# Screenplay text loaded.
# Wonder Woman: 175 matches found
# Extracted 175 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wonder Woman_0451279.txt
# Processing file: X Men Origins Wolverine_0458525.txt
# Screenplay text loaded.
# X Men Origins Wolverine: 155 matches found
# Extracted 155 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\X Men Origins Wolverine_0458525.txt
# Processing file: X Men_0120903.txt
# Screenplay text loaded.
# X Men: 207 matches found
# Extracted 207 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\X Men_0120903.txt
# Processing file: xXx_0295701.txt
# Screenplay text loaded.
# xXx: 152 matches found
# Extracted 152 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\xXx_0295701.txt
# Processing file: Yes Man_1068680.txt
# Screenplay text loaded.
# Yes Man: 160 matches found
# Extracted 160 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Yes Man_1068680.txt
# Processing file: You Only Live Twice_0062512.txt
# Screenplay text loaded.
# You Only Live Twice: 170 matches found
# Extracted 170 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\You Only Live Twice_0062512.txt
# Processing file: Your Highness_1240982.txt
# Screenplay text loaded.
# Your Highness: 183 matches found
# Extracted 183 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Your Highness_1240982.txt
# Processing file: Zodiac_0443706.txt
# Screenplay text loaded.
# Zodiac: 254 matches found
# Extracted 254 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Zodiac_0443706.txt
# Processing file: Zootopia_2948356.txt
# Screenplay text loaded.
# Zootopia: 188 matches found
# Extracted 188 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Zootopia_2948356.txt
# Summary list: [('10 Cloverfield Lane', 133), ('10 Things I Hate About You', 122), ('12 Monkeys', 176), ('12 Years a Slave', 155), ('127 Hours', 460), ('1408', 240), ('15 Minutes', 107), ('16 Blocks', 167), ('17 Again', 132), ('1917', 78), ('2012', 302), ('21 Grams', 175), ('21 Jump Street', 162), ('28 Weeks Later', 210), ('3 10 to Yuma', 187), ('30 Days of Night', 189), ('30 Minutes or Less', 129), ('42', 260), ('47 Ronin', 230), ('8MM', 284), ('A Beautiful Day in the Neighborhood', 130), ('A Beautiful Mind', 198), ('A Christmas Story', 190), ('A Dangerous Method', 137), ('A Few Good Men', 157), ('A Good Year', 195), ('A History of Violence', 128), ('A Mighty Heart', 180), ('A Monster Calls', 43), ('A Night at the Roxbury', 215), ('A Nightmare on Elm Street 4 The Dream Master', 175), ('A Nightmare on Elm Street', 157), ('A Perfect Getaway', 161), ('A Quiet Place', 209), ('A Scanner Darkly', 210), ('A Simple Favor', 183), ('A Simple Plan', 252), ('A Single Man', 185), ('About Time', 171), ('Absolute Power', 354), ('Ad Astra', 171), ('After Earth', 434), ('Air Force One', 338), ('Alfie', 168), ('Alice in Wonderland', 201), ('Alien Covenant', 160), ('Alien Resurrection', 171), ('Aliens', 201), ('Alien', 278), ('Ali', 210), ('All About Steve', 194), ('All the King s Men', 112), ('All the Money in the World', 213), ('Almost Famous', 185), ('Alone in the Dark', 162), ('Amadeus', 228), ('Amelia', 178), ('American Gangster', 310), ('American History X', 187), ('American Hustle', 174), ('American Outlaws', 169), ('American Psycho', 71), ('American Splendor', 212), ('American Ultra', 188), ('An Officer and a Gentleman', 156), ('Anaconda', 223), ('Analyze That', 251), ('Analyze This', 180), ('Anastasia', 151), ('Angel Eyes', 154), ('Angels Demons', 212), ('Animal Kingdom', 176), ('Anna Karenina', 265), ('Annabelle', 150), ('Annie Hall', 145), ('Annihilation', 159), ('Anonymous', 220), ('Antitrust', 262), ('Antz', 85), ('Any Given Sunday', 213), ('Apocalypse Now', 324), ('April Fool s Day', 172), ('Aquaman', 168), ('Arbitrage', 121), ('Argo', 325), ('Arrival', 168), ('Arthur', 159), ('As Above So Below', 139), ('Assassination Nation', 155), ('Assassins', 182), ('At First Sight', 155), ('Atomic Blonde', 164), ('Atonement', 171), ('August Osage County', 225), ('Austin Powers International Man of Mystery', 224), ('Austin Powers The Spy Who Shagged Me', 199), ('Autumn in New York', 152), ('Avatar', 251), ('Avengers Endgame', 271), ('Awakenings', 155), ('Awake', 144), ('Baby Driver', 142), ('Back to the Future Part II', 187), ('Back to the Future', 273), ('Bad Santa', 151), ('Bad Teacher', 155), ('Bad Times at the El Royale', 221), ('Barry Lyndon', 242), ('Basquiat', 141), ('Batman Begins', 330), ('Batman Forever', 169), ('Batman Returns', 275), ('Batman Robin', 206), ('Batman v Superman Dawn of Justice', 216), ('Batman', 253), ('Bats', 138), ('Battle for the Planet of the Apes', 52), ('Battle of the Sexes', 159), ('Beasts of No Nation', 162), ('Beasts of the Southern Wild', 136), ('Beauty and the Beast', 3), ('Beauty and the Beast', 175), ('Beavis and Butt Head Do America', 180), ('Beetlejuice', 218), ('Before Midnight', 25), ('Before Sunrise', 45), ('Before Sunset', 16), ('Being John Malkovich', 331), ('Beloved', 215), ('Beneath the Planet of the Apes', 206), ('Beowulf', 175), ('Beverly Hills Cop', 215), ('Big Eyes', 175), ('Big Fish', 207), ('Big Trouble in Little China', 146), ('Big', 0), ('Bill Ted Face the Music', 296), ('Bill Ted s Bogus Journey', 297), ('Black Christmas', 289), ('Black Hawk Down', 292), ('Black Panther', 201), ('Black Rain', 194), ('Black Swan', 151), ('BlacKkKlansman', 193), ('Blade Runner', 133), ('Blade Trinity', 209), ('Blade', 179), ('Blast from the Past', 197), ('Blue Valentine', 247), ('Body Double', 173), ('Body of Lies', 211), ('Boiler Room', 218), ('Bonnie and Clyde', 196), ('Book of Shadows Blair Witch 2', 148), ('Born on the Fourth of July', 153), ('Bottle Rocket', 110), ('Bound', 179), ('Boy Erased', 177), ...
# Summary of processed files saved to data/screenplay_data/data/scene_separated_texts/processed_files_summary.csv
