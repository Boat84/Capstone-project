# %%
import os
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, pipeline
import torch
import re
import numpy as np
# Out:
# WARNING:tensorflow:From c:\Users\an_na\Documents\Arbeit\Data Science Weiterbildung\capstone\capstone_test\Capstone-project\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# os.makedirs('data/screenplay_data/data/scene_sentiment_vader')

# %%
import os
import re
import csv
import pandas as pd
import numpy as np

def list_csv_files(directory_path):
    # Lists all CSV files in the given directory.
    csv_files = [os.path.join(directory_path, f) for f in os.listdir(directory_path) if f.endswith('.csv')]
    return csv_files

def remove_ext_int_lines(text):
    # Remove all lines that include EXT or INT
    lines = text.split('\n')
    cleaned_lines = [line for line in lines if not line.strip().startswith(('EXT', 'INT'))]
    cleaned_text = '\n'.join(cleaned_lines)
    return cleaned_text

def get_features_df(file):
    # Step 1: Read CSV file into df_1
    df_1 = pd.read_csv(file)
    
    # Step 2: Extract name and ID number from file name
    pattern = r"^(.*)_(\d+)\.csv$"  # Assuming ID number is digits only
    match = re.match(pattern, os.path.basename(file))
    
    if match:
        name = match.group(1)
        id_number = match.group(2)
    else:
        raise ValueError("String format is incorrect")
    
    # Step 3: Get average, mean_squared_deviation, num of turns, and mean squared deviation from sentiment analysis
    average = df_1['Compound'].mean()
    mean_squared_deviation = ((df_1['Compound'] - average) ** 2).mean()
    compound_values = df_1['Compound'].values
    sign_changes = np.sign(compound_values[:-1]) * np.sign(compound_values[1:])
    num_turns = int(np.sum(sign_changes == -1))
    scenes_count = len(df_1['Compound'])

    return name, id_number, average, mean_squared_deviation, num_turns, scenes_count

# # Example usage:
# file_path = 'data/scene_separated_analysed_vader_new2/2 Broke Girls_1845307.csv'  # Replace with your actual file path
# features = get_features_df(file_path)
# print(features)

# Processes all CSV files in the given directory, computes statistics, and writes them to a new CSV file.
def statistic_sentiment_all_csv(dir, dir_to_csv_file):
    # dir: Path to the directory containing CSV files.
    # dir_to_csv_file: Path to the output directory for CSV file.
 
    try:
        csv_files = list_csv_files(dir)
        
        Name = []
        Id = []
        Sentiment_score_average = []
        Sentiment_score_mean_squared_deviation = []
        Sentiment_num_turns = []
        Scenes_count = []

        for file in csv_files:
            print(f"Processing file: {file}")
            name, id_number, average, mean_squared_deviation, num_turns, scenes_count = get_features_df(file)
            Name.append(name)
            Id.append(id_number)
            Sentiment_score_average.append(average)
            Sentiment_score_mean_squared_deviation.append(mean_squared_deviation)
            Sentiment_num_turns.append(num_turns)
            Scenes_count.append(scenes_count)

        if not os.path.exists(dir_to_csv_file):
            os.makedirs(dir_to_csv_file)
        
        csv_sum = os.path.join(dir_to_csv_file, 'sentiment_summ.csv')
        with open(csv_sum, 'w', newline='') as csvfile:
            csv_writer = csv.writer(csvfile)
            csv_writer.writerow(['Name', 'Id', 'Sentiment_score_average', 'Sentiment_score_mean_squared_deviation', 'Sentiment_num_turns', 'Scenes_count'])
            for i in range(len(Name)):
                csv_writer.writerow([Name[i], Id[i], Sentiment_score_average[i], Sentiment_score_mean_squared_deviation[i], Sentiment_num_turns[i], Scenes_count[i]])

        print("Statistics saved to", csv_sum)

    except Exception as e:
        print(f"An error occurred: {str(e)}")


dir = 'data\screenplay_data\data\scene_separated_analysed_vader'  # Replace with your path
dir_to_csv_file = 'data\screenplay_data\data\scene_sentiment_vader'  # Replace with your path
statistic_sentiment_all_csv(dir, dir_to_csv_file)
# Out:
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\10 Cloverfield Lane_1179933.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\10 Things I Hate About You_0147800.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\101 Days of 101 Dalmatians_0249328.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\12 Angry Men_0118528.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\12 Monkeys_0114746.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\12 Years a Slave_2024544.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\127 Hours_1542344.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\13 13 13_2991516.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\1408_0450385.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\1492 Conquest of Paradise_0103594.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\15 Minutes_0179626.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\16 Blocks_0450232.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\17 Again_0974661.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\1917_8579674.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\1976 l lection du Parti qu b cois_11327984.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\2 Broke Girls_1845307.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\2 Guns a Grenade a Pizza Guy_1871996.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\2001 A Space Road Odyssey_0288910.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\2010 The Odyssey Continues_0235153.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\2012_1190080.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\20th Century Women_4385888.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\21 Grams_0315733.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\21 Jump Street_1232829.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\22 July_7280898.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\25th Hour_0307901.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\28 Days Later_0289043.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\28 Days_0191754.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\28 Weeks Later_0463854.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\29th Street Highlander 2 The Quickening Billy Bathgate Year of the Gun_6099126.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\3 10 to Yuma_0381849.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\3 Godfathers_0040064.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\3 Idiots_1187043.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\30 Days of Night_0389722.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\30 Minutes or Less_1622547.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\30 Rock_0496424.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\3000_4759852.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\300_0416449.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\40 Year Old Virgin_0887155.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\42_0453562.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\47 Ronin_1335975.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\48 Hrs_0083511.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\50 50_4487264.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\500 Days of Summer_1022603.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\53 1_4329278.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\8 Mile_0298203.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\84C MoPic_0096744.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\8MM_0134273.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\9 millimeter_0118542.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\9 to 5_0080319.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\99 Homes_2891174.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Beautiful Day in the Neighborhood_3224458.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Beautiful Mind_0268978.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Bucket of Blood_0112594.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Child Is Born The Scottish Doctor_0899329.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Christmas Carol_0044008.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Christmas Story_0085334.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Clockwork Orange_0066921.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Coriolanus rny k ban_2245685.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Dangerous Method_1571222.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Death in the Gunj_5918074.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Dry White Season_0097243.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Fantastic Woman_5639354.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Few Good Men_0104257.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Few Good Men_0849162.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Fish Called Wanda_0095159.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Good Year_0401445.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Goofy Movie_0113198.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Hard Day s Night_0058182.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Hard Days Night_0581729.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A History of Violence_0399146.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A I Artificial Intelligence_0212720.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Message for Peace Making Hotel Rwanda_0476811.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Mighty Heart_0829459.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A Monkey in Winter_0056636.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\A
csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\An Act of Murder_0040072.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\An Adventure in Space and Time_2663812.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\An Affair to Remember_0050105.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\An American Tragedy_0021607.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\An American Werewolf in London_0082010.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\An American Werewolf in Paris_0118604.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\An Education_1174732.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\An Officer and a Gentleman_0084434.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\An Unconventional Love Story The Making of Last Chance Harvey_2043778.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Anaconda_0118615.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Analyze That_0289848.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Analyze This_0122933.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Anastasia_0118617.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Anatomy of a Murder_0052561.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Anchorman The Legend of Ron Burgundy_0357413.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\And Away We Go_1003594.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Angel Eyes_0225071.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Angels Demons_0808151.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Angels with Dirty Faces_0029870.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Animal Among Us_3612008.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Animal Kingdom_1313092.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Anna Karenina_1781769.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Annabelle_3322940.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Annie Hall_0075686.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Annihilation_2798920.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Anomalisa_2401878.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Anonymous_1521197.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Another Year_1431181.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Antitrust_0218817.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Antz_0120587.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Any Given Sunday_0146838.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Apache Drums_0043291.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Apocalypse Now_0078788.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\April Fool s Day_0090655.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\April in Paris_0044370.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Apt Pupil_0118636.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Aquaman_1477834.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Arbitrage_1764183.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Arctic Blue_0106303.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Are We Done Yet_0422774.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Argo_1024648.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Armageddon_0120591.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Armstrong_4451006.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Army of Darkness_0106308.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Arrival_2543164.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Arsenic and Old Lace_0036613.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Arthur_1334512.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\As Above So Below_2870612.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\As Good as It Gets_0119822.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Asesinos por naturaleza_0309302.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Assassination Nation_6205872.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Assassins_0112401.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Asylum_0068230.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\At First Sight_0132512.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\ATM_1603257.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Atomic Blonde_2406566.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Atonement_0783233.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\Au pan coup_0290137.csv
# Processing file: data\screenplay_data\data\scene_separated_analysed_vader\August Osage County_1322269.csv.csv
# An error occurred: String format is incorrect

# %%
import pandas as pd
df = pd.read_csv('data/screenplay_data/data/scene_sentiment_vader/sentiment_summ.csv')
print(df['Id'].nunique())
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('data/screenplay_data/data/scene_sentiment_vader/sentiment_summ.csv')
#       3 print(df['Id'].nunique())
#       4 df.head()
#
# File c:\Users\an_na\Documents\Arbeit\Data Science Weiterbildung\capstone\capstone_test\Capstone-project\.venv\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\an_na\Documents\Arbeit\Data Science Weiterbildung\capstone\capstone_test\Capstone-project\.venv\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Users\an_na\Documents\Arbeit\Data Science Weiterbildung\capstone\capstone_test\Capstone-project\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\an_na\Documents\Arbeit\Data Science Weiterbildung\capstone\capstone_test\Capstone-project\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Users\an_na\Documents\Arbeit\Data Science Weiterbildung\capstone\capstone_test\Capstone-project\.venv\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/screenplay_data/data/scene_sentiment_vader/sentiment_summ.csv'
