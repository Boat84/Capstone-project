# %%
import re
import chardet
import os
import csv

# %%
# function to detect file encoding

def detect_encoding(file_path):
    with open(file_path, 'rb') as file:
        raw_data = file.read()
    result = chardet.detect(raw_data)
    encoding = result.get('encoding')

    # condition to respect ascii or no encoding
    if encoding is None:
        print("No encoding detected, defaulting to utf-8")
        encoding = 'utf-8'
    elif encoding.lower() == 'ascii':
        print("Detected ASCII encoding, defaulting to utf-8")
        encoding = 'utf-8'
    else:
        print(f"Detected encoding: {encoding}")
        
    return encoding

# %%
# function to read screenplay

def read_screenplay(file_path):
    encoding = detect_encoding(file_path)
    if encoding.lower() == 'ascii':
        encoding = 'utf-8'  # fallback to UTF-8 if ASCII is detected
    with open(file_path, 'r', encoding=encoding, errors='ignore') as file:
        text = file.read()
    print("Screenplay text loaded.")
    return text

# %%
# function to identify scenes

def identify_scenes(text, title):
    
    # compile the regular expressions
    ext_pattern = re.compile(r'^EXT[.:]', re.MULTILINE)
    int_pattern = re.compile(r'^INT[.:]', re.MULTILINE)
    uppercase_pattern = re.compile(r'^[A-Z0-9\s:\(\)\-\.\:]+$', re.MULTILINE)
    fade_pattern = re.compile(r'\bFADE OUT', re.MULTILINE)
    cut_pattern = re.compile(r'\bCUT TO', re.MULTILINE)
    dissolve_pattern = re.compile(r'\bDISSOLVE', re.MULTILINE)
    smash_pattern = re.compile(r'\bSMASH CUT', re.MULTILINE)
    
    # split text into lines
    lines = text.splitlines()
    
    # remove leading whitespace from each line
    lines = [line.lstrip() for line in lines]
    
    # list to store matched lines
    matches = []
    
    # iterate through each line and search for EXT and INT matches
    # number matches to ensure uniqueness
    match_counter = 1
    for line in lines:
        if ext_pattern.search(line) or int_pattern.search(line):
            # append scene heading and scene counter
            matches.append(f"{line} SCENE{match_counter:03d}")
            match_counter += 1
    
    # if less than 150 EXT and INT matches are found, include uppercase lines
    if len(matches) < 150:
        for line in lines:
            if uppercase_pattern.match(line) and line not in matches:
                words = line.split()
                if len(words) >= 3:  # Ensure it consists of at least three words
                    matches.append(f"{line} SCENE{match_counter:03d}")
                    match_counter += 1
    
    # if still less than 150 matches, include fade, cut, dissolve and smash
    if len(matches) < 150:
        for line in lines:
            if (fade_pattern.search(line) or cut_pattern.search(line) or
                dissolve_pattern.search(line) or smash_pattern.search(line)) and line not in matches:
                matches.append(f"{line} SCENE{match_counter:03d}")
                match_counter += 1
    
    print(f"{title}: {len(matches)} matches found")
    
    return matches

# %%
# function to identify scenes

def extract_scenes(text, matches):
    # dictionary to store scene heading (key) and scene content (value)
    scenes = {}

    # split up scene heading and number again and find line in screenplay
    for i in range(len(matches)):
        scene_title = matches[i]
        numbered_scene_title = scene_title.split(' SCENE')[0]
        scene_id = scene_title.split(' SCENE')[1]
        start_pos = text.find(numbered_scene_title)

        # define scene start and end position
        if i + 1 < len(matches):
            next_scene_title = matches[i + 1].split(' SCENE')[0]
            end_pos = text.find(next_scene_title, start_pos + len(numbered_scene_title))
        else:
            end_pos = len(text)

        # create scene text from scene title to next scene title
        scene_text = text[start_pos:end_pos].strip()
        unique_scene_title = f"{scene_id} {numbered_scene_title}"
        scenes[unique_scene_title] = scene_text

    print(f"Extracted {len(scenes)} scenes")  # debugging statement
    
    return scenes

# %%
# function to clean scene text

def clean_scene_text(scene_text):
    # remove leading and trailing whitespace from each line
    lines = scene_text.splitlines()
    cleaned_lines = [re.sub(r'\s+', ' ', line.strip()) for line in lines]
    cleaned_text = "\n".join(cleaned_lines)
    return cleaned_text

# %%
# function to save scene separated text to new file

def save_scenes_to_file(file_path, scenes):
    # determine new file path
    new_dir = 'data/screenplay_data/data/scene_separated_texts'
    if not os.path.exists(new_dir):
        os.makedirs(new_dir)
    
    filename = os.path.basename(file_path)
    new_file_path = os.path.join(new_dir, filename)
    
    # write scenes to new file
    with open(new_file_path, 'w', encoding='utf-8') as file:
        file.write(f"Scene count: {len(scenes)}\n\n")
        
        for i, (scene_title, scene_content) in enumerate(scenes.items(), start=1):
            cleaned_scene_content = clean_scene_text(scene_content)
            file.write("=" * 50 + "\n") # 50 * = as scene separation
            file.write(f"{cleaned_scene_content}\n\n")
    
    print(f"Scene-separated screenplay saved to {new_file_path}")

# %%
# function that combines previous functions

def process_screenplay(file_path):
    # extract movie title from filename
    filename = os.path.basename(file_path)
    title = filename.split('_')[0]
    
    # read screenplay text
    text = read_screenplay(file_path)
    
    # identify scene headings
    scene_headings = identify_scenes(text, title)
    
    # extract scenes
    scenes = extract_scenes(text, scene_headings)
    
    # save formatted text to new file
    save_scenes_to_file(file_path, scenes)
    
    return title, len(scene_headings)  # return title and number of scenes for summary

# %%
# function to process all screenplays in the raw_texts folder and create summary file

def process_all_screenplays(folder_path, summary_file_path):
    summary = []

    # iterate over screenplays in folder
    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):
            file_path = os.path.join(folder_path, filename)
            print(f"Processing file: {filename}")
            
            try:
                # process screenplay and get title and scene count
                title, scene_count = process_screenplay(file_path)
                
                # append to summary list
                summary.append((title, scene_count))
            except Exception as e:
                print(f"Error processing file {filename}: {e}")
    
    print("Summary list:", summary)  # debugging addition

    try:
        # save summary to csv
        with open(summary_file_path, 'w', encoding='utf-8', newline='') as summary_file:
            writer = csv.writer(summary_file)
            writer.writerow(['Title', 'Scene Count'])
            writer.writerows(summary)
        
        print(f"Summary of processed files saved to {summary_file_path}")
    except Exception as e:
        print(f"Error saving summary to CSV: {e}")

# %%
# run the function

folder_path = 'data/screenplay_data/data/raw_texts/raw_texts'
summary_file_path = 'data/screenplay_data/data/scene_separated_texts/processed_files_summary.csv'
process_all_screenplays(folder_path, summary_file_path)
# Out:
# Processing file: 10 Cloverfield Lane_1179933.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 10 Cloverfield Lane: 233 matches found
# Extracted 233 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\10 Cloverfield Lane_1179933.txt
# Processing file: 10 Things I Hate About You_0147800.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# 10 Things I Hate About You: 182 matches found
# Extracted 182 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\10 Things I Hate About You_0147800.txt
# Processing file: 101 Days of 101 Dalmatians_0249328.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 101 Days of 101 Dalmatians: 521 matches found
# Extracted 521 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\101 Days of 101 Dalmatians_0249328.txt
# Processing file: 12 Angry Men_0118528.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 12 Angry Men: 110 matches found
# Extracted 110 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts
txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 29th Street Highlander 2 The Quickening Billy Bathgate Year of the Gun: 10 matches found
# Extracted 10 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\29th Street Highlander 2 The Quickening Billy Bathgate Year of the Gun_6099126.txt
# Processing file: 3 10 to Yuma_0381849.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 3 10 to Yuma: 164 matches found
# Extracted 164 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\3 10 to Yuma_0381849.txt
# Processing file: 3 Godfathers_0040064.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# 3 Godfathers: 162 matches found
# Extracted 162 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\3 Godfathers_0040064.txt
# Processing file: 3 Idiots_1187043.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 3 Idiots: 179 matches found
# Extracted 179 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\3 Idiots_1187043.txt
# Processing file: 30 Days of Night_0389722.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 30 Days of Night: 162 matches found
# Extracted 162 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\30 Days of Night_0389722.txt
# Processing file: 30 Minutes or Less_1622547.txt
# Detected encoding: MacRoman
# Screenplay text loaded.
# 30 Minutes or Less: 191 matches found
# Extracted 191 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\30 Minutes or Less_1622547.txt
# Processing file: 30 Rock_0496424.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 30 Rock: 66 matches found
# Extracted 66 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\30 Rock_0496424.txt
# Processing file: 3000_4759852.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 3000: 256 matches found
# Extracted 256 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\3000_4759852.txt
# Processing file: 300_0416449.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 300: 112 matches found
# Extracted 112 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\300_0416449.txt
# Processing file: 40 Year Old Virgin_0887155.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 40 Year Old Virgin: 170 matches found
# Extracted 170 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\40 Year Old Virgin_0887155.txt
# Processing file: 42_0453562.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 42: 368 matches found
# Extracted 368 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\42_0453562.txt
# Processing file: 47 Ronin_1335975.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 47 Ronin: 272 matches found
# Extracted 272 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\47 Ronin_1335975.txt
# Processing file: 48 Hrs_0083511.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# 48 Hrs: 97 matches found
# Extracted 97 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\48 Hrs_0083511.txt
# Processing file: 50 50_4487264.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# 50 50: 171 matches found
# Extracted 171 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\50 50_4487264.txt
# Processing file: 500 Days of Summer_1022603.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# 500 Days of Summer: 176 matches found
# Extracted 176 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\500 Days of Summer_1022603.txt
# Processing file: 53 1_4329278.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 53 1: 16 matches found
# Extracted 16 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\53 1_4329278.txt
# Processing file: 8 Mile_0298203.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 8 Mile: 24 matches found
# Extracted 24 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\8 Mile_0298203.txt
# Processing file: 84C MoPic_0096744.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# 84C MoPic: 6 matches found
# Extracted 6 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\84C MoPic_0096744.txt
# Processing file: 8MM_0134273.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# 8MM: 282 matches found
# Extracted 282 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\8MM_0134273.txt
# Processing file: 9 millimeter_0118542.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# 9 millimeter: 282 matches found
# Extracted 282 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\9 millimeter_0118542.txt
# Processing file: 9 to 5_0080319.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 9 to 5: 167 matches found
# Extracted 167 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\9 to 5_0080319.txt
# Processing file: 99 Homes_2891174.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# 99 Homes: 198 matches found
# Extracted 198 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\99 Homes_2891174.txt
# Processing file: A Beautiful Day in the Neighborhood_3224458.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A Beautiful Day in the Neighborhood: 159 matches found
# Extracted 159 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Beautiful Day in the Neighborhood_3224458.txt
# Processing file: A Beautiful Mind_0268978.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A Beautiful Mind: 193 matches found
# Extracted 193 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Beautiful Mind_0268978.txt
# Processing file: A Bucket of Blood_0112594.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# A Bucket of Blood: 69 matches found
# Extracted 69 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Bucket of Blood_0112594.txt
# Processing file: A Child Is Born The Scottish Doctor_0899329.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A Child Is Born The Scottish Doctor: 227 matches found
# Extracted 227 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Child Is Born The Scottish Doctor_0899329.txt
# Processing file: A Christmas Carol_0044008.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A Christmas Carol: 203 matches found
# Extracted 203 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Christmas Carol_0044008.txt
# Processing file: A Christmas Story_0085334.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A Christmas Story: 171 matches found
# Extracted 170 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Christmas Story_0085334.txt
# Processing file: A Clockwork Orange_0066921.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A Clockwork Orange: 93 matches found
# Extracted 93 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Clockwork Orange_0066921.txt
# Processing file: A Coriolanus rny k ban_2245685.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# A Coriolanus rny k ban: 155 matches found
# Extracted 155 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Coriolanus rny k ban_2245685.txt
# Processing file: A Dangerous Method_1571222.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A Dangerous Method: 178 matches found
# Extracted 178 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Dangerous Method_1571222.txt
# Processing file: A Death in the Gunj_5918074.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A Death in the Gunj: 156 matches found
# Extracted 156 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Death in the Gunj_5918074.txt
# Processing file: A Dry White Season_0097243.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# A Dry White Season: 158 matches found
# Extracted 158 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Dry White Season_0097243.txt
# Processing file: A Fantastic Woman_5639354.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A Fantastic Woman: 168 matches found
# Extracted 168 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Fantastic Woman_5639354.txt
# Processing file: A Few Good Men_0104257.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# A Few Good Men: 162 matches found
# Extracted 162 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Few Good Men_0104257.txt
# Processing file: A Few Good Men_0849162.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# A Few Good Men: 161 matches found
# Extracted 161 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Few Good Men_0849162.txt
# Processing file: A Fish Called Wanda_0095159.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A Fish Called Wanda: 221 matches found
# Extracted 221 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Fish Called Wanda_0095159.txt
# Processing file: A Good Year_0401445.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A Good Year: 290 matches found
# Extracted 290 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Good Year_0401445.txt
# Processing file: A Goofy Movie_0113198.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A Goofy Movie: 90 matches found
# Extracted 90 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Goofy Movie_0113198.txt
# Processing file: A Hard Day s Night_0058182.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A Hard Day s Night: 84 matches found
# Extracted 84 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Hard Day s Night_0058182.txt
# Processing file: A Hard Days Night_0581729.txt
# Detected encoding: ISO-8859-1
# Screenplay text loaded.
# A Hard Days Night: 83 matches found
# Extracted 83 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Hard Days Night_0581729.txt
# Processing file: A History of Violence_0399146.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A History of Violence: 167 matches found
# Extracted 167 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A History of Violence_0399146.txt
# Processing file: A I Artificial Intelligence_0212720.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A I Artificial Intelligence: 56 matches found
# Extracted 56 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A I Artificial Intelligence_0212720.txt
# Processing file: A Message for Peace Making Hotel Rwanda_0476811.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# A Message for Peace Making Hotel Rwanda: 196 matches found
# Extracted 196 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Message for Peace Making Hotel Rwanda_0476811.txt
# Processing file: A Mighty Heart_0829459.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A Mighty Heart: 91 matches found
# Extracted 91 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Mighty Heart_0829459.txt
# Processing file: A Monkey in Winter_0056636.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A Monkey in Winter: 22 matches found
# Extracted 22 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Monkey in Winter_0056636.txt
# Processing file: A Monster Calls_3416532.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# A Monster Calls: 30 matches found
# Extracted 30 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Monster Calls_3416532.txt
# Processing file: A Most Violent Year_5169360.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# A Most Violent Year: 234 matches found
# Extracted 234 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Most Violent Year_5169360.txt
# Processing file: A Night at the Roxbury_0120770.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# A Night at the Roxbury: 251 matches found
# Extracted 244 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Night at the Roxbury_0120770.txt
# Processing file: A Nightmare on Elm Street 2 Freddy s Revenge_0089686.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# A Nightmare on Elm Street 2 Freddy s Revenge: 274 matches found
# Extracted 274 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\A Nightmare on Elm Street 2 Freddy s Revenge_0089686.txt
# Processing file: A Nightmare on Elm Street 3 Dream Warriors_0093629.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# A
 168 matches found
# Extracted 168 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\About Schmidt_0257360.txt
# Processing file: About Time_2194499.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# About Time: 793 matches found
# Extracted 793 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\About Time_2194499.txt
# Processing file: Above the Law_0094602.txt
# Detected encoding: ISO-8859-1
# Screenplay text loaded.
# Above the Law: 325 matches found
# Extracted 325 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Above the Law_0094602.txt
# Processing file: Absolute Power_0118548.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Absolute Power: 361 matches found
# Extracted 361 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Absolute Power_0118548.txt
# Processing file: Ace Ventura Pet Detective_0109040.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Ace Ventura Pet Detective: 235 matches found
# Extracted 235 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Ace Ventura Pet Detective_0109040.txt
# Processing file: Ad Astra_2935510.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Ad Astra: 150 matches found
# Extracted 150 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Ad Astra_2935510.txt
# Processing file: Adaptation_2980718.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Adaptation: 202 matches found
# Extracted 202 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Adaptation_2980718.txt
# Processing file: Affliction_0118564.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Affliction: 213 matches found
# Extracted 206 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Affliction_0118564.txt
# Processing file: After Earth_1815862.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# After Earth: 846 matches found
# Extracted 846 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\After Earth_1815862.txt
# Processing file: After Hours Revisits Rock Stars Lamb Entrees and Late Night_5070224.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# After Hours Revisits Rock Stars Lamb Entrees and Late Night: 172 matches found
# Extracted 172 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\After Hours Revisits Rock Stars Lamb Entrees and Late Night_5070224.txt
# Processing file: After Life_0838247.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# After Life: 183 matches found
# Extracted 183 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\After Life_0838247.txt
# Processing file: After School Special_0371514.txt
# Detected encoding: MacRoman
# Screenplay text loaded.
# After School Special: 260 matches found
# Extracted 260 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\After School Special_0371514.txt
# Processing file: After the Wedding_7985692.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# After the Wedding: 213 matches found
# Extracted 213 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\After the Wedding_7985692.txt
# Processing file: Agnes of God_0088683.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Agnes of God: 99 matches found
# Extracted 99 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Agnes of God_0088683.txt
# Processing file: Air Force One_0118571.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Air Force One: 337 matches found
# Extracted 337 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Air Force One_0118571.txt
# Processing file: Airforce One 2 Revenge of President Dracula_1843432.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Airforce One 2 Revenge of President Dracula: 337 matches found
# Extracted 337 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Airforce One 2 Revenge of President Dracula_1843432.txt
# Processing file: Airplane II The Sequel_0083530.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Airplane II The Sequel: 257 matches found
# Extracted 257 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Airplane II The Sequel_0083530.txt
# Processing file: Airplane_0080339.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Airplane: 335 matches found
# Extracted 335 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Airplane_0080339.txt
# Processing file: Al Wazeer Jay_6543896.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Al Wazeer Jay: 168 matches found
# Extracted 168 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Al Wazeer Jay_6543896.txt
# Processing file: Aladdin_0103639.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Aladdin: 1 matches found
# Extracted 1 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Aladdin_0103639.txt
# Processing file: Alfie_0375173.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Alfie: 186 matches found
# Extracted 186 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alfie_0375173.txt
# Processing file: Alfred Hitchcock and the Making of Psycho_1362861.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Alfred Hitchcock and the Making of Psycho: 258 matches found
# Extracted 258 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alfred Hitchcock and the Making of Psycho_1362861.txt
# Processing file: Alice in Wonderland_1014759.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Alice in Wonderland: 252 matches found
# Extracted 252 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alice in Wonderland_1014759.txt
# Processing file: Alien Covenant_2316204.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Alien Covenant: 159 matches found
# Extracted 159 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alien Covenant_2316204.txt
# Processing file: Alien Engineering Part 1_1713914.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Alien Engineering Part 1: 270 matches found
# Extracted 270 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alien Engineering Part 1_1713914.txt
# Processing file: Alien Nation_0094631.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Alien Nation: 174 matches found
# Extracted 174 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alien Nation_0094631.txt
# Processing file: Alien Resurrection_0118583.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Alien Resurrection: 169 matches found
# Extracted 169 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alien Resurrection_0118583.txt
# Processing file: Alien vs Predator_9824546.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Alien vs Predator: 248 matches found
# Extracted 248 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alien vs Predator_9824546.txt
# Processing file: Aliens vs Predator_7039058.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Aliens vs Predator: 248 matches found
# Extracted 248 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Aliens vs Predator_7039058.txt
# Processing file: Aliens_0090605.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Aliens: 192 matches found
# Extracted 192 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Aliens_0090605.txt
# Processing file: Alien_0078748.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Alien: 253 matches found
# Extracted 253 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alien_0078748.txt
# Processing file: Alien_0103644.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Alien: 172 matches found
# Extracted 172 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alien_0103644.txt
# Processing file: Ali_0248667.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Ali: 198 matches found
# Extracted 198 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Ali_0248667.txt
# Processing file: All About Eve_0042192.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# All About Eve: 92 matches found
# Extracted 92 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\All About Eve_0042192.txt
# Processing file: All About Steve_0881891.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# All About Steve: 194 matches found
# Extracted 194 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\All About Steve_0881891.txt
# Processing file: All God s Children Can Dance_0847214.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# All God s Children Can Dance: 212 matches found
# Extracted 212 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\All God s Children Can Dance_0847214.txt
# Processing file: All Is Lost_2017038.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# All Is Lost: 119 matches found
# Extracted 119 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\All Is Lost_2017038.txt
# Processing file: All Is True_9206798.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# All Is True: 245 matches found
# Extracted 245 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\All Is True_9206798.txt
# Processing file: All That Jazz_0078754.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# All That Jazz: 361 matches found
# Extracted 361 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\All That Jazz_0078754.txt
# Processing file: All the King s Men_0041113.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# All the King s Men: 122 matches found
# Extracted 122 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\All the King s Men_0041113.txt
# Processing file: All the Money in the World_5294550.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# All the Money in the World: 188 matches found
# Extracted 188 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\All the Money in the World_5294550.txt
# Processing file: All the President s Men_0074119.txt
# Detected encoding: MacRoman
# Screenplay text loaded.
# All the President s Men: 363 matches found
# Extracted 363 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\All the President s Men_0074119.txt
# Processing file: All You Need Is Love_1725862.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# All You Need Is Love: 266 matches found
# Extracted 266 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\All You Need Is Love_1725862.txt
# Processing file: Almost Famous_0181875.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Almost Famous: 81 matches found
# Extracted 81 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Almost Famous_0181875.txt
# Processing file: Alone in the Dark_0369226.txt
# Detected encoding: ISO-8859-1
# Screenplay text loaded.
# Alone in the Dark: 280 matches found
# Extracted 280 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Alone in the Dark_0369226.txt
# Processing file: Altered Carbon Episode 1 Spoiler Free Review Out of the Past_13255492.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Altered Carbon Episode 1 Spoiler Free Review Out of the Past: 126 matches found
# Extracted 126 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Altered Carbon Episode 1 Spoiler Free Review Out of the Past_13255492.txt
# Processing file: Altered States_0080360.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Altered States: 205 matches found
# Extracted 205 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Altered States_0080360.txt
# Processing file: Am I Blue Part 2_0826905.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Am I Blue Part 2: 154 matches found
# Extracted 154 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Am I Blue Part 2_0826905.txt
# Processing file: Am lie_0211915.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Am lie: 26 matches found
# Extracted 26 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Am lie_0211915.txt
# Processing file: Amadeus_0086879.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Amadeus: 174 matches found
# Extracted 174 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Amadeus_0086879.txt
# Processing file: Amelia_1129445.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Amelia: 211 matches found
# Extracted 211 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Amelia_1129445.txt
# Processing file: American Animals_6212478.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# American Animals: 348 matches found
# Extracted 348 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Animals_6212478.txt
# Processing file: American Beauty_0169547.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# American Beauty: 162 matches found
# Extracted 162 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Beauty_0169547.txt
# Processing file: American Bully_1169133.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# American Bully: 309 matches found
# Extracted 309 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Bully_1169133.txt
# Processing file: American Gangster_0765429.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# American Gangster: 329 matches found
# Extracted 329 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Gangster_0765429.txt
# Processing file: American Gods 1x1 REACTION The Bone Orchard_11563674.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# American Gods 1x1 REACTION The Bone Orchard: 157 matches found
# Extracted 157 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Gods 1x1 REACTION The Bone Orchard_11563674.txt
# Processing file: American Graffiti_0069704.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# American Graffiti: 30 matches found
# Extracted 30 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Graffiti_0069704.txt
# Processing file: American History X_0120586.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# American History X: 272 matches found
# Extracted 271 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American History X_0120586.txt
# Processing file: American Horror Story_1844624.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# American Horror Story: 188 matches found
# Extracted 188 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Horror Story_1844624.txt
# Processing file: American Hustle_1800241.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# American Hustle: 395 matches found
# Extracted 395 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Hustle_1800241.txt
# Processing file: American Madness_0022626.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# American Madness: 307 matches found
# Extracted 306 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Madness_0022626.txt
# Processing file: American Milkshake_2254364.txt
# Detected encoding: MacRoman
# Screenplay text loaded.
# American Milkshake: 195 matches found
# Extracted 195 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Milkshake_2254364.txt
# Processing file: American Outlaws_0244000.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# American Outlaws: 256 matches found
# Extracted 256 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Outlaws_0244000.txt
# Processing file: American Psycho_0144084.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# American Psycho: 98 matches found
# Extracted 98 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Psycho_0144084.txt
# Processing file: American Shaolin_0101327.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# American Shaolin: 150 matches found
# Extracted 150 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Shaolin_0101327.txt
# Processing file: American Splendor_0305206.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# American Splendor: 304 matches found
# Extracted 304 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Splendor_0305206.txt
# Processing file: American Ultra_3316948.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# American Ultra: 203 matches found
# Extracted 203 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Ultra_3316948.txt
# Processing file: American Werewolf in London_1789110.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# American Werewolf in London: 119 matches found
# Extracted 118 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\American Werewolf in London_1789110.txt
# Processing file: Amour_1602620.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Amour: 65 matches found
# Extracted 65 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Amour_1602620.txt
# Processing file: An Act of Murder_0040072.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# An Act of Murder: 47 matches found
# Extracted 47 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\An Act of Murder_0040072.txt
# Processing file: An Adventure in Space and Time_2663812.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# An Adventure in Space and Time: 204 matches found
# Extracted 203 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\An Adventure in Space and Time_2663812.txt
# Processing file: An Affair to Remember_0050105.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# An Affair to Remember: 157 matches found
# Extracted 157 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\An Affair to Remember_0050105.txt
# Processing file: An American Tragedy_0021607.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# An American Tragedy: 15 matches found
# Extracted 15 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\An American Tragedy_0021607.txt
# Processing file: An American Werewolf in London_0082010.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# An American Werewolf in London: 119 matches found
# Extracted 118 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\An American Werewolf in London_0082010.txt
# Processing file: An American Werewolf in Paris_0118604.txt
# ...
# Processing file: Willow_0096446.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Willow: 267 matches found
# Extracted 267 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Willow_0096446.txt
# Processing file: Win Win_1606392.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Win Win: 162 matches found
# Extracted 162 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Win Win_1606392.txt
# Processing file: Wind Chill_0486051.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Wind Chill: 211 matches found
# Extracted 207 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wind Chill_0486051.txt
# Processing file: Wind River_5362988.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Wind River: 150 matches found
# Extracted 150 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wind River_5362988.txt
# Processing file: Winter s Bone_1399683.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Winter s Bone: 121 matches found
# Extracted 121 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Winter s Bone_1399683.txt
# Processing file: Witchery_0096453.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Witchery: 154 matches found
# Extracted 154 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Witchery_0096453.txt
# Processing file: Withnail I_0094336.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Withnail I: 0 matches found
# Extracted 0 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Withnail I_0094336.txt
# Processing file: Witness for the Prosecution_0051201.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Witness for the Prosecution: 145 matches found
# Extracted 145 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Witness for the Prosecution_0051201.txt
# Processing file: Witness_0090329.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Witness: 162 matches found
# Extracted 162 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Witness_0090329.txt
# Processing file: Wives and Lovers_0057688.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Wives and Lovers: 165 matches found
# Extracted 165 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wives and Lovers_0057688.txt
# Processing file: Wizard of Oz_8035824.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Wizard of Oz: 99 matches found
# Extracted 99 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wizard of Oz_8035824.txt
# Processing file: Woman in Gold_2404425.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Woman in Gold: 225 matches found
# Extracted 225 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Woman in Gold_2404425.txt
# Processing file: Women in Love_0066579.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Women in Love: 170 matches found
# Extracted 170 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Women in Love_0066579.txt
# Processing file: Wonder Boys_0185014.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Wonder Boys: 105 matches found
# Extracted 105 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wonder Boys_0185014.txt
# Processing file: Wonder Woman_0451279.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Wonder Woman: 322 matches found
# Extracted 322 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wonder Woman_0451279.txt
# Processing file: Wonderland_0335563.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Wonderland: 289 matches found
# Extracted 289 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wonderland_0335563.txt
# Processing file: Wonderstruck_5208216.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Wonderstruck: 151 matches found
# Extracted 151 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wonderstruck_5208216.txt
# Processing file: Working for the Man_1364020.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Working for the Man: 245 matches found
# Extracted 244 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Working for the Man_1364020.txt
# Processing file: Working Girl_0096463.txt
# Detected encoding: ISO-8859-1
# Screenplay text loaded.
# Working Girl: 0 matches found
# Extracted 0 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Working Girl_0096463.txt
# Processing file: Wreck It Ralph_10946860.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Wreck It Ralph: 234 matches found
# Extracted 234 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wreck It Ralph_10946860.txt
# Processing file: Wrongfully Accused_0120901.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Wrongfully Accused: 356 matches found
# Extracted 356 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Wrongfully Accused_0120901.txt
# Processing file: X Men Origins Wolverine_0458525.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# X Men Origins Wolverine: 240 matches found
# Extracted 240 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\X Men Origins Wolverine_0458525.txt
# Processing file: X Men Origins Wolverine_3012064.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# X Men Origins Wolverine: 263 matches found
# Extracted 263 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\X Men Origins Wolverine_3012064.txt
# Processing file: X Men The Animated Series_0103584.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# X Men The Animated Series: 276 matches found
# Extracted 276 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\X Men The Animated Series_0103584.txt
# Processing file: X Men_0120903.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# X Men: 276 matches found
# Extracted 276 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\X Men_0120903.txt
# Processing file: X2 X Men United_0290334.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# X2 X Men United: 200 matches found
# Extracted 200 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\X2 X Men United_0290334.txt
# Processing file: XTRMN8mm_5660414.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# XTRMN8mm: 282 matches found
# Extracted 282 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\XTRMN8mm_5660414.txt
# Processing file: xXx_0295701.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# xXx: 265 matches found
# Extracted 265 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\xXx_0295701.txt
# Processing file: Y The Last Man_8042500.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Y The Last Man: 210 matches found
# Extracted 210 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Y The Last Man_8042500.txt
# Processing file: Year One_1045778.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Year One: 161 matches found
# Extracted 161 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Year One_1045778.txt
# Processing file: Yes Man_1068680.txt
# Detected encoding: MacRoman
# Screenplay text loaded.
# Yes Man: 303 matches found
# Extracted 303 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Yes Man_1068680.txt
# Processing file: You Came Along_0038263.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# You Came Along: 140 matches found
# Extracted 140 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\You Came Along_0038263.txt
# Processing file: You Can Count on Me_0203230.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# You Can Count on Me: 170 matches found
# Extracted 170 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\You Can Count on Me_0203230.txt
# Processing file: You ll Never Walk Alone in This Town Again_0639513.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# You ll Never Walk Alone in This Town Again: 251 matches found
# Extracted 251 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\You ll Never Walk Alone in This Town Again_0639513.txt
# Processing file: You Only Live Twice_0062512.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# You Only Live Twice: 233 matches found
# Extracted 233 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\You Only Live Twice_0062512.txt
# Processing file: You ve Got Mail_0128853.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# You ve Got Mail: 169 matches found
# Extracted 169 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\You ve Got Mail_0128853.txt
# Processing file: You Were Never Really Here_5742374.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# You Were Never Really Here: 164 matches found
# Extracted 164 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\You Were Never Really Here_5742374.txt
# Processing file: Young Adult_1625346.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Young Adult: 197 matches found
# Extracted 197 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Young Adult_1625346.txt
# Processing file: Young Frankenstein_0072431.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Young Frankenstein: 267 matches found
# Extracted 267 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Young Frankenstein_0072431.txt
# Processing file: Young Soul Rebels_0103312.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Young Soul Rebels: 90 matches found
# Extracted 90 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Young Soul Rebels_0103312.txt
# Processing file: Your Highness_1240982.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Your Highness: 213 matches found
# Extracted 213 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Your Highness_1240982.txt
# Processing file: Zero Dark Thirty_1790885.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Zero Dark Thirty: 229 matches found
# Extracted 229 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Zero Dark Thirty_1790885.txt
# Processing file: Zodiac_0443706.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Zodiac: 729 matches found
# Extracted 729 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Zodiac_0443706.txt
# Processing file: Zootopia_2948356.txt
# Detected encoding: utf-8
# Screenplay text loaded.
# Zootopia: 230 matches found
# Extracted 230 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Zootopia_2948356.txt
# Processing file: Zulu Dawn_0080180.txt
# Detected ASCII encoding, defaulting to utf-8
# Screenplay text loaded.
# Zulu Dawn: 41 matches found
# Extracted 41 scenes
# Scene-separated screenplay saved to data/screenplay_data/data/scene_separated_texts\Zulu Dawn_0080180.txt
# Summary list: [('10 Cloverfield Lane', 233), ('10 Things I Hate About You', 182), ('101 Days of 101 Dalmatians', 521), ('12 Angry Men', 110), ('12 Monkeys', 173), ('12 Years a Slave', 313), ('127 Hours', 206), ('13 13 13', 93), ('1408', 256), ('1492 Conquest of Paradise', 156), ('15 Minutes', 150), ('16 Blocks', 164), ('17 Again', 153), ('1917', 114), ('1976 l lection du Parti qu b cois', 168), ('2 Broke Girls', 268), ('2 Guns a Grenade a Pizza Guy', 224), ('2001 A Space Road Odyssey', 751), ('2010 The Odyssey Continues', 247), ('2012', 255), ('20th Century Women', 186), ('21 Grams', 82), ('21 Jump Street', 246), ('22 July', 226), ('25th Hour', 148), ('28 Days Later', 177), ('28 Days', 260), ('28 Weeks Later', 233), ('29th Street Highlander 2 The Quickening Billy Bathgate Year of the Gun', 10), ('3 10 to Yuma', 164), ('3 Godfathers', 162), ('3 Idiots', 179), ('30 Days of Night', 162), ('30 Minutes or Less', 191), ('30 Rock', 66), ('3000', 256), ('300', 112), ('40 Year Old Virgin', 170), ('42', 368), ('47 Ronin', 272), ('48 Hrs', 97), ('50 50', 171), ('