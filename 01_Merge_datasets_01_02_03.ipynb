# %%
import pandas as pd

df = pd.read_csv('data/movie_meta_data.csv')

# %%
df.shape
# Out:
# (2858, 25)

# %%
df.columns
# Out:
# Index(['imdbid', 'title', 'akas', 'year', 'metascore', 'imdb user rating',
#        'number of imdb user votes', 'awards', 'opening weekend', 'producers',
#        'budget', 'script department', 'production companies', 'writers',
#        'directors', 'casting directors', 'cast', 'countries', 'age restrict',
#        'plot', 'plot outline', 'keywords', 'genres', 'taglines', 'synopsis'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2858 entries, 0 to 2857
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   imdbid                     2858 non-null   int64
#  1   title                      2858 non-null   object
#  2   akas                       2652 non-null   object
#  3   year                       2858 non-null   int64
#  4   metascore                  2858 non-null   int64
#  5   imdb user rating           2858 non-null   int64
#  6   number of imdb user votes  2858 non-null   int64
#  7   awards                     2243 non-null   object
#  8   opening weekend            1739 non-null   object
#  9   producers                  2640 non-null   object
#  10  budget                     1624 non-null   object
#  11  script department          2220 non-null   object
#  12  production companies       2682 non-null   object
#  13  writers                    2696 non-null   object
#  14  directors                  2658 non-null   object
#  15  casting directors          2141 non-null   object
#  16  cast                       2806 non-null   object
#  17  countries                  2678 non-null   object
#  18  age restrict               2526 non-null   object
#  19  plot                       2709 non-null   object
#  20  plot outline               2457 non-null   object
#  21  keywords                   2601 non-null   object
#  22  genres                     2846 non-null   object
#  23  taglines                   2256 non-null   object
#  24  synopsis                   1852 non-null   object
# dtypes: int64(5), object(20)
# memory usage: 558.3+ KB

# %%
df.duplicated(subset=['imdbid']).sum()
# Out:
# 0

# %%
df['age restrict'].isna().sum()
# Out:
# 332

# %%
# rename columns to replace space with underscore
df.columns = df.columns.str.replace(' ', '_')

# %%
# drop unnecessary columns

# list of columns to drop
columns_to_drop = ['akas', 'metascore', 'imdb_user_rating', 'number_of_imdb_user_votes', 'awards', 'producers', 'script_department', 'writers', 'casting_directors', 'plot', 'plot_outline', 'keywords',
                   'taglines', 'synopsis', 'budget', 'year', 'opening_weekend', 'production_companies', 'directors', 'cast', 'countries', 'age_restrict', 'genres']

# Drop the columns
df = df.drop(columns=columns_to_drop)

# %%
df.head()
# Out:
#    imdbid                   title
# 0  120770  A Night at the Roxbury
# 1  132512          At First Sight
# 2  118661            The Avengers
# 3  215545              Bamboozled
# 4  118715        The Big Lebowski

# %%
df2 = pd.read_csv('data/movie_metadata_set_01.csv')
df2.head()
# Out:
#     imdbid                              title  year age_rating  \
# 0  9114286     Black Panther: Wakanda Forever  2022      PG-13
# 1  1630029           Avatar: The Way of Water  2022      PG-13
# 2  5884796                              Plane  2023          R
# 3  6710474  Everything Everywhere All at Once  2022          R
# 4  5433140                             Fast X  2023        NaN
#
#                         genre  \
# 0    Action, Adventure, Drama
# 1  Action, Adventure, Fantasy
# 2            Action, Thriller
# 3   Action, Adventure, Comedy
# 4      Action, Crime, Mystery
#
#                                          description  \
# 0  The people of Wakanda fight to protect their h...
# 1  Jake Sully lives with his newfound family form...
# 2  A pilot finds himself caught in a war zone aft...
# 3  A middle-aged Chinese immigrant is swept up in...
# 4  Dom Toretto and his family are targeted by the...
#
#                        director  runtime_minutes  production_budget  \
# 0                  Ryan Coogler              NaN                NaN
# 1                 James Cameron            192.0        460000000.0
# 2          Jean-François Richet              NaN                NaN
# 3  Dan Kwan, \nDaniel Scheinert              NaN                NaN
# 4               Louis Leterrier              NaN                NaN
#
#    domestic_gross  worldwide_gross
# 0             NaN              NaN
# 1     667830256.0     2.265936e+09
# 2             NaN              NaN
# 3             NaN              NaN
# 4             NaN              NaN

# %%
df2.shape
# Out:
# (369726, 11)

# %%
df2.duplicated(subset=['imdbid']).sum()
# Out:
# 126529

# %%
# merge df with df2 on 'imdbid'
merged_df = pd.merge(df, df2, on='imdbid', how='left')

# %%
merged_df.head()
# Out:
#    imdbid                 title_x                 title_y  year age_rating  \
# 0  120770  A Night at the Roxbury  A Night at the Roxbury  1998      PG-13
# 1  132512          At First Sight          At First Sight  1999      PG-13
# 2  118661            The Avengers            The Avengers  1998      PG-13
# 3  118661            The Avengers            The Avengers  1998      PG-13
# 4  118661            The Avengers            The Avengers  1998      PG-13
#
#                        genre  \
# 0     Comedy, Music, Romance
# 1             Drama, Romance
# 2  Action, Adventure, Sci-Fi
# 3  Action, Adventure, Sci-Fi
# 4  Action, Adventure, Sci-Fi
#
#                                          description             director  \
# 0  Two dim-witted brothers dream of owning their ...     John Fortenberry
# 1  A blind man has an operation to regain his sig...        Irwin Winkler
# 2  Two British Agents team up to stop Sir August ...  Jeremiah S. Chechik
# 3  Two British Agents team up to stop Sir August ...  Jeremiah S. Chechik
# 4  Two British Agents team up to stop Sir August ...  Jeremiah S. Chechik
#
#    runtime_minutes  production_budget  domestic_gross  worldwide_gross
# 0             82.0         17000000.0      30331165.0     3.033116e+07
# 1            128.0         40000000.0      22365133.0     2.236513e+07
# 2            143.0        225000000.0     623357910.0     1.515100e+09
# 3             89.0         60000000.0      23385416.0     4.858542e+07
# 4            143.0        225000000.0     623357910.0     1.515100e+09

# %%
merged_df.shape
# Out:
# (5736, 12)

# %%
merged_df.duplicated(subset=['imdbid']).sum()
# Out:
# 2878

# %%
# drop duplicate rows based on 'imdbid', keep only the first occurrence
df = merged_df.drop_duplicates(subset=['imdbid'], keep='first')

# %%
df.shape
# Out:
# (2858, 12)

# %%
df.production_budget.isna().sum()
# Out:
# 1620

# %%
# drop rows that don't have budget, gross
df = df.dropna(subset=['production_budget'])

# %%
df.shape
# Out:
# (1238, 12)

# %%
# new feature: 'financial_success' = 'worldwide_gross' > 'production_budget'*2
df['financial_success'] = (df['worldwide_gross'] > df['production_budget'] * 2).astype(int)

# %%
# new feature 'ROI' (return on investment)
df['ROI'] = df['worldwide_gross'] / df['production_budget']

# %%
# check for unique values in age_rating
df.age_rating.unique()
# Out:
# array(['PG-13', 'R', 'PG', nan, 'G', 'TV-MA', '18+', 'Unrated',
#        'Not Rated', 'Passed', 'U', 'UA', 'GP', 'Approved', 'A', '13+'],
#       dtype=object)

# %%
# check for missing age ratings
age_ratings_missing = ['Unrated', 'Not Rated', 'Passed', 'Approved']
# 3576   10.549451
# 3921   10.436481
# 4186  100.134665
# 4284    2.659504
# 4681    2.211204
# 4955   32.120996
# 5037    2.313742
# 5177    5.208342
# 5410    1.389345
# 5578    2.993200

# %%
df[df.age_rating.isna()]
# Out:
#        imdbid                                     title_x  \
# 168     32976                                     Rebecca
# 299     41113                          All the King's Men
# 2807   164167                       Sidewalks of New York
# 2919  2901014  A Beautiful Day in the Neighborhood - IMDb
# 3500    37884                            The Lost Weekend
# 3620  1729217                                    Playback
# 3813    58648                           The Thin Red Line
#
#                                   title_y  year age_rating  \
# 168                               Rebecca  1940        NaN
# 299                    All the King's Men  1949        NaN
# 2807                Sidewalks of New York  1923        NaN
# 2919  A Beautiful Day in the Neighborhood   NaN        NaN
# 3500                     The Lost Weekend  1945        NaN
# 3620                             Playback  1962        NaN
# 3813                    The Thin Red Line  1964        NaN
#
#                           genre  \
# 168   Drama, Film-Noir, Mystery
# 299            Drama, Film-Noir
# 2807               Drama, Sport
# 2919                  Biography
# 3500           Drama, Film-Noir
# 3620     Crime, Drama, Thriller
# 3813                 Drama, War
#
#                                             description          director  \
# 168   A self-conscious woman juggles adjusting to he...  Alfred Hitchcock
# 299   The rise and fall of a corrupt politician, who...     Robert Rossen
# 2807                                         Add a Plot       Lester Park
# 2919  A look at the life and early work of legendary...   Marielle Heller
# 3500  The desperate life of a chronic alcoholic is f...      Billy Wilder
# 3620  A young policeman becomes involved with a glam...  Quentin Lawrence
# 3813  In Guadalcanal during World War II, a private ...     Andrew Marton
#
#       runtime_minutes  production_budget  domestic_gross  worldwide_gross  \
# 168             130.0          1288000.0       6000000.0        6002370.0
# 299             128.0         55000000.0       7221458.0        9521458.0
# 2807            108.0          1000000.0       2402459.0        3575308.0
# 2919            109.0         45000000.0      61696436.0       68590003.0
# 3500            101.0          1250000.0      11000000.0       11000000.0
# 3620             98.0          1500000.0           264.0          54945.0
# 3813            170.0         52000000.0      36400491.0       97709034.0
#
#       financial_success       ROI
# 168                   1  4.660225
# 299                   0  0.173117
# 2807                  1  3.575308
# 2919                  0  1.524222
# 3500                  1  8.800000
# 3620                  0  0.036630
# 3813                  0  1.879020

# %%
# update missing age ratings
df.loc[df['imdbid'] == 77402, 'age_rating'] = 'X'
df.loc[df['imdbid'] == 88993, 'age_rating'] = 'X'
df.loc[df['imdbid'] == 45793, 'age_rating'] = '13+'
df.loc[df['imdbid'] == 25316, 'age_rating'] = 'PG'
df.loc[df['imdbid'] == 47437, 'age_rating'] = 'PG'
df.loc[df['imdbid'] == 16220, 'age_rating'] = 'PG'
df.loc[df['imdbid'] == 2321549, 'age_rating'] = 'PG-13'
df.loc[df['imdbid'] == 53604, 'age_rating'] = 'PG-13'
df.loc[df['imdbid'] == 38348, 'age_rating'] = 'PG'
df.loc[df['imdbid'] == 34587, 'age_rating'] = 'PG-13'
df.loc[df['imdbid'] == 61811, 'age_rating'] = 'PG-13'
df.loc[df['imdbid'] == 56172, 'age_rating'] = 'PG-13'
df.loc[df['imdbid'] == 54135, 'age_rating'] = 'PG-13'
df.loc[df['imdbid'] == 47296, 'age_rating'] = 'PG-13'
df.loc[df['imdbid'] == 63522, 'age_rating'] = 'M'
df.loc[df['imdbid'] == 31381, 'age_rating'] = 'PG'
df.loc[df['imdbid'] == 24216, 'age_rating'] = 'PG'
df.loc[df['imdbid'] == 48281, 'age_rating'] = 'PG'
df.loc[df['imdbid'] == 5074352, 'age_rating'] = 'PG-13'
df.loc[df['imdbid'] == 49513, 'age_rating'] = 'PG-13'
df.loc[df['imdbid'] == 55824, 'age_rating'] = 'X'
df.loc[df['imdbid'] == 63350, 'age_rating'] = 'X'
df.loc[df['imdbid'] == 57115, 'age_rating'] = 'PG'
df.loc[df['imdbid'] == 32976, 'age_rating'] = 'PG-13'
df.loc[df['imdbid'] == 41113, 'age_rating'] = 'PG-13'
df.loc[df['imdbid'] == 164167, 'age_rating'] = 'G'
df.loc[df['imdbid'] == 2901014, 'age_rating'] = 'PG'
df.loc[df['imdbid'] == 2901014, 'year'] = 2019
df.loc[df['imdbid'] == 37884, 'age_rating'] = 'PG-13'
df.loc[df['imdbid'] == 1729217, 'age_rating'] = 'PG-13'
df.loc[df['imdbid'] == 58648, 'age_rating'] = 'R'

# %%
# map numbers to the respective age ratings

# age rating to numerical value
age_rating_mapping = {
    'G': 0,
    'PG': 6,
    'PG-13': 13,
    'R': 17,
    'NC-17': 18,
    'M': 17,
    'X': 17,
    'TV-MA': 17,
    '18+': 18,
    'U': 0,
    'UA': 13,
    'GP': 6,
    'A': 18,
    '13+': 13
}

# create new column 'age_rating_number' based on mapping
df['age_rating_number'] = df['age_rating'].map(age_rating_mapping)

# %%
df.isna().sum()
# Out:
# imdbid               0
# title_x              0
# title_y              0
# year                 0
# age_rating           0
# genre                0
# description          0
# director             0
# runtime_minutes      0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# financial_success    0
# ROI                  0
# age_rating_number    0
# dtype: int64

# %%
# create dummies for genres

# generate dummy variables with column prefix
genre_dummies = df['genre'].str.get_dummies(sep=', ').rename(lambda x: 'genre_' + x.lower(), axis=1).astype(int)

# concatenate genre dummies with original DataFrame
df = pd.concat([df, genre_dummies], axis=1)

# %%
df.columns
# Out:
# Index(['imdbid', 'title_x', 'title_y', 'year', 'age_rating', 'genre',
#        'description', 'director', 'runtime_minutes', 'production_budget',
#        'domestic_gross', 'worldwide_gross', 'financial_success', 'ROI',
#        'age_rating_number', 'genre_action', 'genre_adventure',
#        'genre_animation', 'genre_biography', 'genre_comedy', 'genre_crime',
#        'genre_drama', 'genre_family', 'genre_fantasy', 'genre_film-noir',
#        'genre_history', 'genre_horror', 'genre_music', 'genre_musical',
#        'genre_mystery', 'genre_romance', 'genre_sci-fi', 'genre_sport',
#        'genre_thriller', 'genre_war', 'genre_western'],
#       dtype='object')

# %%
# drop column title_y and rename title_x
df = df.drop(columns=['title_y'])
df = df.rename(columns={'title_x': 'title'})

# %%
# output df to csv
output_file = 'data/movie_metadata_final.csv'
df.to_csv(output_file, index=False)
